# %% [markdown]
# # Function for closing the mesh (Necessary for calculating the volume

# %%
import numpy as np

'''
in this part of the code, the boundarys will be closed with the function close_boundary.

'''
from ddgclib._particle_liquid_bridge_20240303 import *

# %%
def close_boundary(HC, boundary_top, boundary_bottom):
    v_avg_top = np.zeros(3)
    for v in boundary_top:
        v_avg_top += v.x_a

    v_avg_top = v_avg_top/len(boundary_top)
    v_avg_bottom = np.zeros(3)
    for v in boundary_bottom:
        v_avg_bottom += v.x_a

    v_avg_bottom = v_avg_bottom/len(boundary_bottom)

    vat = HC.V[tuple(v_avg_top)]
    for v in boundary_top:
        v.connect(vat)

    vab = HC.V[tuple(v_avg_bottom)]
    for v in boundary_bottom:
        v.connect(vab)

    #boundary_top.append(vat)
    #print(f'vat = {vat}')
    #HC.V.remove(vat)
    #boundary_bottom.append(vab)
    return HC, boundary_top, boundary_bottom, vat, vab

# %% [markdown]
# # Functions for the contact-angle calculation

# %%
def b_disc_angle(v, r, bV, print_out=True):
    """
    Takes boundary vertex v and outputs the contact angle

    v: vertex
    N: normal vector estimating the direction of the surface (liquid to gas)
    """

    N_f0 = v.x_a - np.array([0.0, 0.0, v.x_a[2]]) # Version from Stefan
    N_f0 = normalized(N_f0)[0]
    F, nn = vectorise_vnn(v)
    c_outd = b_curvatures_hn_ij_c_ij(F, nn, n_i = N_f0)

    vij = []
    for vn in v.nn:
        if vn in bV:
            continue
        else:
            vij.append(vn)

    if 0:
        for vn in v.nn:
            if vn in bV:
                vij.append(vn)


    E_ij = vij[0].x_a - v.x_a
    E_ik = vij[1].x_a - v.x_a
    E_ij_ik = np.cross(E_ij, E_ik)
    E_ij_ik_norm = np.linalg.norm(E_ij_ik) # || E_ij ^ E_ik ||
    dir_vec = E_ij_ik / E_ij_ik_norm

    if np.dot(N_f0, dir_vec) < 0:
        dir_vec = - dir_vec

    #K_H_i = c_outd['K_H_i']
    HNdA_i = c_outd['HNdA_i']
    C_ij = c_outd['C_ij']
    #HN_i = np.sum(HNdA_i) / np.sum(C_ij)
    n_i = c_outd['n_i']
    HN_i = np.sum(np.dot(HNdA_i, n_i)) / np.sum(C_ij)
    K_H_i = (HN_i/ 2.0)**2


    #TODO: Adjust for other geometric approximations:
    #l_a = 2 * np.pi * r / len(bV)  # arc length
    Xi = 1
    # Gauss-Bonnet: int_M K dA + int_dM kg ds = 2 pi Xi
    # NOTE: Area should be height of spherical cap    # h = R - r * 4np.tan(theta_p)
    # Approximate radius of the great shpere K = (1/R)**2:
    #r =  #TODO: test if this is a good approximation
    R_approx = 1 / np.sqrt(K_H_i)
    theta_p_approx = np.arccos(min([r / R_approx, 1]))
    h = R_approx - r * np.tan(theta_p_approx)
    A_approx = 2 * np.pi * R_approx * h  # Area of spherical cap

    # A_approx  # Approximate area of the spherical cap
    kg_ds = 2 * np.pi * Xi - K_H_i * (A_approx)
    ds = 2 * np.pi * r  # Arc length of whole spherical cap
    k_g = kg_ds / ds  # / 2.0
    phi_est = np.arctan(R_approx * k_g)

    if print_out:
       # print(f'theta_p_approx = {theta_p_approx * 180 / np.pi}')
       # print(f'cos = {[r / R_approx]}')
        print(f'phi_est = {phi_est * 180 / np.pi}')
        print(f'E_ij = {E_ij}')
        print(f'E_ik = {E_ik}')
        print(f'E_ij_ik = {E_ij_ik}')
        print(f'dir_vec = {dir_vec}')
        print(f'np.dot(E_ij_ik_norm, dir_vec) = {np.dot(E_ij_ik_norm, dir_vec)}')
        print(f'E_ij_ik_norm = {E_ij_ik_norm}')
        print(f'vij = {vij}')

    return phi_est, dir_vec, E_ij, E_ik, E_ij_ik# , de # (sum of edge lengths)

# %% [markdown]
# # Functions for Particle-Particle liquid bridge

# %%
import copy


def fun_liquid_bridge_N(d_l, d_u, length, refinement, theta_c, tau, gamma, breaking_condition, itermax, contact_angle = True, load_activated = False,itermax_load = 10, save_activated = False,volume_constraint = False, V_init = 1):
    '''
    length = length of the inital cone [m]
    tau = size of time step [-]
    d_l = diameter one the lower site of the initial cyliner [m]
    d_u = diameter one the upper site of the initial cyliner [m]
    refinement = number of refinement of the mesh [-]
    theta_c = value of the contact angle in radian [rad]
    gamma = surface_tension [N/m]
    breaking_condition = when this value is reached, the simulation is finished [m]
    itermax = another breaking condition depending on the iteration steps [-]
    contact_angle = is the contact angle actived
    load_activated = with this parameter you have the choice to load a complex instead of creating a new on.
        if load_activated = False: A new mesh will be generated
    itermax_load = number of iteration of the loading complex (necessary paramter for loading the complex function:
    save_activated = with this parameter you have the choice to save the final complex
        if save_activated=False: Nothing happens
        if save_activated=True: The complex will saved under a savename depending on the inital parameters
    '''

    starttime = timer()
    print('Simulation is started!')
    print('-------------------------------------')

    r_l = d_l / 2
    r_u = d_u / 2

    v_l = 0
    v_u = length +v_l

    r_approx = length/2.0  # approximate radius of the contact angle spherical cap
    '''
    -----------------------------------------------------------
    From here, the mesh for an open truncated cone is meshed
    '''
    if load_activated:
        load_filename = 'dl'+str(d_l)+'_du'+str(d_u)+'_l'+str(length)+'_ref'+str(refinement)+'_contactangle'+str(theta_c)+'_tau'+str(tau)+'_itermax'+str(itermax_load)+'.json'
        HC = Complex(3)
        HC.load_complex(load_filename)
    else:
        HC, bV, K_f, H_f, neck_verts, neck_sols = truncated_cone_initial_N(r_l, r_u, length, refinement)


    # Define bottom boundary condition
    boundary_bottom = []
    N_f0_vectors_pairs = []
    for v in HC.V:
        #if v.x[2] == v_l:
        #if v.x[2] >= v_l - 1e-5 and v.x[2] <= v_l + 1e-5 or v.x[2] == v_l:
        if v.x[2] == v_l:
          #  print(f'v.x bottom ={v.x}')
            boundary_bottom.append(v)
    # Define top boundary condition
    boundary_top = []
    for v in HC.V:
        #if v.x[2] == v_u:
        #if v.x[2] >= v_u - 1e-5 and v.x[2] <= v_u + 1e-5 or v.x[2] == v_u:
        if v.x[2] == v_u:
           # print(f'v.x top ={v.x}')
            boundary_top.append(v)

    # runvariable for the iteration tracking
    residual_iteration = 0

    #HC, boundary_top, boundary_bottom, vat, vab = close_boundary(HC, boundary_top, boundary_bottom)
    iteration_list = []

    # list to track the progress from df
    df_list_max = []
    df_list_min = []

    # list to track the progress of HNdA
    dHNdA_list_min = []
    dHNdA_list_max = []

    res_list = []

    volume_list = []
    contact_angle_list_bottom   = []
    contact_angle_list_top      = []

    '''
    ---------------------------------------------------------------------------------------------------------------------------
    From here, the optimization is started
    '''
    iters = 0
    while True:

        if itermax == 0:
            print('Mesh is generated. Optimization was not carried out because itermax = 0.')
            break

        if iters > itermax:
            endtime = timer()
            print('-------------------------------------')
            print("Too many iterations! Simulation is canceled!")
            print(f"Time elapsed for canceled Simulation: {endtime-starttime:.2f} s")
            break
        '''
        Calculating the volume of the hole mesh in every volume
        '''

        if 1:
            V_current = 0
            number_v = 0
            HC, boundary_top, boundary_bottom, vat, vab = close_boundary(HC, boundary_top, boundary_bottom) # closing the boundary

            for v in HC.V:
                number_v += 1
                V_ijk = volume(v)
                V_current += np.sum(V_ijk)

            V_current = V_current/12
           # print(f'V_current = {V_current}')
            volume_list.append(V_current)

            if 0: # V_init >= V_current and iters == 0:
                print(f'error: Volume constraint - Initial volume is bigger than the current volume')
                print(f'Proof the volume constraint!')
                print(f'Simulation will be canceled!')
                break
                dV = 0

            else:
                dV = (V_init-V_current)/V_init


            HC.V.remove(vat) # Open the boundary (Important, otherwise the angle-calculation will not work)
            HC.V.remove(vab) # Open the boundary (Important, otherwise the angle-calculation will not work)

        # dummy list to find the maximum df
        df_list_dummy       = []
        dHNdA_list_dummy    = []
        v_boundary_interior = {}

        contact_angle_list_bottom_dummy = []
        contact_angle_list_top_dummy   = []
       # print(f'number of vertexes = {number_v}')
        cHC = copy.copy(HC)

        for v in cHC.V:
            N_f0 = v.x_a - np.array([0.0, 0.0, v.x_a[2]])
            N_f0 = normalized(N_f0)[0]
            N_f0_vectors_pairs.append([v.x_a, N_f0])

            dV_dummy = dV
            # Define bottom boundary condition
            if v in set(boundary_bottom):
                phi_est, dir_vec, E_ij, E_ik, E_ij_ik = b_disc_angle(v, r=r_approx, bV=boundary_bottom, print_out=False)
                contact_angle_list_bottom_dummy.append(phi_est)
                dE = np.linalg.norm(E_ij) + np.linalg.norm(E_ij)

                dV_dummy = 0

                for vnn in v.nn:
                    if (vnn in boundary_bottom): # or (vnn in boundary_top):
                        continue
                    else:
                        F_b = (np.cos(phi_est) - np.cos(theta_c)) *gamma * dE
                        vnn_factor = F_b * dir_vec
                        #vnn_factor = np.dot(vnn_factor,dir_vec)*dir_vec
                        #vnn_factor = np.dot(F_b,N_f0)*N_f0

                        try:
                            v_boundary_interior[vnn.x] += vnn_factor
                        except KeyError:
                            v_boundary_interior[vnn.x] = vnn_factor
                continue

            # Define top boundary condition
            if v in set(boundary_top):
                phi_est, dir_vec, E_ij, E_ik, E_ij_ik = b_disc_angle(v, r=r_approx, bV=boundary_top, print_out=False)
               # contact_angle_list_top_dummy.append(phi_est)
                dE = np.linalg.norm(E_ij) + np.linalg.norm(E_ij)
                dV_dummy = 0
                for vnn in v.nn:
                    if (vnn in boundary_top): # or (vnn in boundary_bottom)
                        continue
                    else:
                        contact_angle_list_top_dummy.append(phi_est)
                        F_b = (np.cos(phi_est) - np.cos(theta_c)) * gamma * dE
                        vnn_factor = F_b * dir_vec
                        #vnn_factor = np.dot(vnn_factor,dir_vec)*dir_vec
                        #vnn_factor = np.dot(F_b,N_f0)*N_f0
                        try:
                            v_boundary_interior[vnn.x] += vnn_factor
                        except KeyError:
                            v_boundary_interior[vnn.x] = vnn_factor
                continue

            # Compute curvature for each interior vertex
            HNdA_i = curvature(v)

            # Enforce boundary contact angle
            db = np.zeros_like(HNdA_i)

            df = - gamma * HNdA_i  # Add compressive force F_c = N_i * (V_initial - V_total)
            #df = np.dot(df, N_f0)*N_f0
           # print(f'v_boundary_interior = {v_boundary_interior}')
            if v.x in v_boundary_interior.keys() and contact_angle:
                db = v_boundary_interior[v.x]  # normalized(HNdA_i)[0]
              #  df = np.zeros_like(HNdA_i)
               # df[0] = 0
               # df[1] = 0
               # df[2] = 0
               # db[2] = 0
            else:
                pass

            # Step in time
            if iters < 1:
                db = np.zeros_like(HNdA_i)
            else:
                db = db

           # db = np.dot(db, dir_vec)*dir_vec
           # df = np.dot(df, N_f0)*N_f0
           # df = - gamma * HNdA_i  # Add compressive force F_c = N_i * (V_initial - V_total)

            #v_new = v.x_a - tau/2 * df  + tau/2 * db old

            if volume_constraint:
                dv = dV_dummy * N_f0
                #print(f'dV = {dV}')
                #print(f'dv = {dv}')

            else:
                dv = np.zeros_like(HNdA_i)

            if contact_angle: # contact angle constraint
                db = np.dot(db, N_f0)*N_f0
            else:
                db = np.zeros_like(HNdA_i)

            v_new = v.x_a - tau/2 * df  + tau/2 * db + tau/2 * dv

            '''
            if contact_angle: # condition if the contact angle is activated
                v_new = v.x_a - tau/2 * df  + tau/2 * db
            else:
                v_new = v.x_a - tau/2 * df
            '''

            #v_new = v.x_a - tau/2 * df
            HC.V.move(v, tuple(v_new))
            df_list_dummy.append(np.linalg.norm(df+db))
            dHNdA_list_dummy.append(np.linalg.norm(HNdA_i))

        #contact_angle_list_bottom_dummy.append(phi_est) theta_p_approx * 180 / np.pi
        contact_angle_list_bottom.append(cal_average(contact_angle_list_bottom_dummy)* 180 / np.pi)
        contact_angle_list_top.append(cal_average(contact_angle_list_top_dummy)* 180 / np.pi)


        # save the maximum and minimum datas for the Residuals
        df_list_max.append(max(df_list_dummy))
        df_list_min.append(min(df_list_dummy))
        # save the numbers of iteration for lately plotting
        iteration_list.append(iters)
        dHNdA_list_max.append(max(dHNdA_list_dummy))
        dHNdA_list_min.append(min(dHNdA_list_dummy))

        print(f'number of iteration ={iters}')
       # print(f'len_boundary_bottom = {len(boundary_bottom)}')
       # print(f'boundary_top = {len(boundary_top)}')


        if iters%100 == 0:
            # print(f"Time elapsed: {complex[6]-complex[5]:.2f} s")
            interimstime = timer()
            print(f"Iteration elapsed: {iters:.0f}")
            print(f"Time elapsed:{interimstime-starttime:.2f} s")
            print(f"Amount of highest displacement: {max(df_list_dummy)*10**6:.2f} mikrometer")


        if max(df_list_dummy) < breaking_condition:
            endtime = timer()
            print('-------------------------------------')
            print("Simulation is finished and is terminated without a problem.")
            print(f"Time elapsed for hole Simulation: {endtime-starttime:.2f} s")
            break

        iters += 1

    if save_activated:
        if load_activated:
            itermax_save = itermax + itermax_load
        else:
            itermax_save = itermax

        save_filename = 'dl'+str(d_l)+'_du'+str(d_u)+'_l'+str(length)+'_ref'+str(refinement)+'_contactangle'+str(theta_c)+'_tau'+str(tau)+'_itermax'+str(itermax_save)+'.json'
        save_complex(HC, save_filename)
        print(f'Complex is saved under the name: {save_filename}.')

    result_dict = {}
    result_dict['HC'] = HC

    result_dict['iteration_list'] = iteration_list
    result_dict['df_list_min'] = df_list_min
    result_dict['df_list_max'] = df_list_max
    result_dict['volume_list'] = volume_list
    result_dict['contact_angle_list_bottom'] = contact_angle_list_bottom
    result_dict['contact_angle_list_top'] = contact_angle_list_top
    result_dict['N_f0_vectors_pairs'] = N_f0_vectors_pairs
    result_dict['dHNdA_list_min'] = dHNdA_list_min
    result_dict['dHNdA_list_max'] = dHNdA_list_max


    return result_dict


    #return (HC, iteration_list, df_list_min, df_list_max, volume_list,contact_angle_list_bottom, contact_angle_list_top, N_f0_vectors_pairs,dHNdA_list_min, dHNdA_list_max)

   # return (HC, iteration_list, df_list_min, df_list_max, volume_list,contact_angle_list_bottom, contact_angle_list_top, N_f0_vectors_pairs,dHNdA_list_min, dHNdA_list_max,contact_angle_list_top_dummy)

# %% [markdown]
# # Variation and execution of the particle-particle-liquid function

# %%
#gamma = 728e-6  # N/m, surface tension of water at 20 deg C
gamma = 0.0728  # N/m, surface tension of water at 20 deg C
refinement= 4 # NOTE: 2 is the minimum refinement needed for the complex to be manifold
'''
d_l = 0.8e-3 # radian on the lower side of the cone
d_l = 1.6e-3 # radian on the lower side of the cone
d_u = 1.6e-3 # diameter on the upper side of the cone
d_u = 1.6e-3 # diameter on the upper side of the cone
d_u = 0.36 * 3e-3
d_l = d_u
length = 0.7e-3 # length of the cone
length = 0.294 * 3e-3
'''



tau = 0.1    # Endtime for calculation
tau = 1    # Endtime for calculation
itermax = 100*1e3 #10*1e3



itermax_load = 25*1e3 # number of iteration of the loaded complex

'''
from Liam 19939
'''
#r_i = 1e-3 # Particle Radian
#r_i = 1.0
#gamma = 72.28

gamma = 2.45e-3  # N/m, surface tension of di-n-butyl phthalate/liquid paraffin mixture
r_i = 15e-3 # Particle Radian

angle = 10 # angle from the liquid bridge depending of the particle-radian
S = 0.1 # dimensionless seperation distance
#S = 0.3 # dimensionless seperation distance

y_i = np.sin(angle * np.pi/180.0) * r_i # calculated radian of the liquid bridge
r_l = y_i
r_u = r_l
length = S * r_i


# TEST angle:
theta_p = 61 * np.pi/180.0  # Three phase contact angle

'''
t_f = 100 # final time of the time step
V_final = 0.084
damping_factor = 1
'''
#length = 2
#d_l = 1
#d_u = d_l


breaking_condition = 1e-9

#dummy_parameter = fun_liquid_bridge(-0.5, 0.5,0, 0,1) # v_l, v_u, tau, tf, d
# def fun_liquid_bridge(d_l, d_u, length, refinement, tau, t_f, gamma, V_final, damping_factor, volume_constraint)
#fun_liquid_bridge_N(d_l, d_u, length, refinement, theta_c, tau, gamma, breaking_condition, itermax):
# def fun_liquid_bridge_test(d_l, d_u, length, refinement, tau, gamma, breaking_condition,itermax):
dummy_parameter2 = fun_liquid_bridge_N(r_l, r_u, length, refinement, theta_p,tau, gamma, breaking_condition,itermax,contact_angle = False, save_activated=True, load_activated=False, itermax_load = itermax_load, volume_constraint=False, V_init= y_i**2 *np.pi * length * 0.01)

# dummy_parameter = fun_liquid_bridge(d_l, d_u, length, refinement, tau, t_f, gamma, V_final, damping_factor, True)
# Out:
# Simulation is started!
# -------------------------------------
# V_current = 1.968466710058971e-09
# number of iteration =0
# Iteration elapsed: 0
# Time elapsed:3.58 s
# Amount of highest displacement: 0.61 mikrometer
# V_current = 1.969478602060591e-09
# number of iteration =1
# V_current = 1.969218092287425e-09
# number of iteration =2
# V_current = 1.9706433943541354e-09
# number of iteration =3
# V_current = 1.968260500292279e-09
# number of iteration =4
# V_current = 1.968831376397041e-09
# number of iteration =5
# V_current = 1.9689750698584476e-09
# number of iteration =6
# V_current = 1.9682687969510457e-09
# number of iteration =7
# V_current = 1.970940022782695e-09
# number of iteration =8
# V_current = 1.970647657410001e-09
# number of iteration =9
# V_current = 1.972465099135532e-09
# number of iteration =10
# V_current = 1.9692037380523428e-09
# number of iteration =11
# V_current = 1.9705897944905733e-09
# number of iteration =12
# V_current = 1.972394952433864e-09
# number of iteration =13
# V_current = 1.9699656404825333e-09
# number of iteration =14
# V_current = 1.970493413885046e-09
# number of iteration =15
# V_current = 1.9701708198273256e-09
# number of iteration =16
# V_current = 1.971960409716937e-09
# number of iteration =17
# V_current = 1.9707831983137376e-09
# number of iteration =18
# V_current = 1.9721421184177504e-09
# number of iteration =19
# V_current = 1.973074139201281e-09
# number of iteration =20
# V_current = 1.970190612045572e-09
# number of iteration =21
# V_current = 1.971115031520564e-09
# number of iteration =22
# V_current = 1.9724598113209584e-09
# number of iteration =23
# V_current = 1.972106266785198e-09
# number of iteration =24
# V_current = 1.9717490165549997e-09
# number of iteration =25
# V_current = 1.972660014511588e-09
# number of iteration =26
# V_current = 1.973991981048327e-09
# number of iteration =27
# V_current = 1.9736245718223975e-09
# number of iteration =28
# V_current = 1.973253706482132e-09
# number of iteration =29
# V_current = 1.9728794464910822e-09
# number of iteration =30
# V_current = 1.972077459854247e-09
# number of iteration =31
# V_current = 1.973394434648637e-09
# number of iteration =32
# V_current = 1.9730106268875784e-09
# number of iteration =33
# V_current = 1.9730483319809674e-09
# number of iteration =34
# V_current = 1.9722336362221363e-09
# number of iteration =35
# V_current = 1.9722654132156976e-09
# number of iteration =36
# V_current = 1.9722944078168363e-09
# number of iteration =37
# V_current = 1.9723206812872206e-09
# number of iteration =38
# V_current = 1.971494085819625e-09
# number of iteration =39
# V_current = 1.9719401133044484e-09
# number of iteration =40
# V_current = 1.974510189878869e-09
# number of iteration =41
# V_current = 1.9706982812158108e-09
# number of iteration =42
# V_current = 1.973689708867683e-09
# number of iteration =43
# V_current = 1.9728500726033892e-09
# number of iteration =44
# V_current = 1.9741359515766434e-09
# number of iteration =45
# V_current = 1.9737172042851033e-09
# number of iteration =46
# V_current = 1.9715928358948933e-09
# number of iteration =47
# V_current = 1.9737244236002287e-09
# number of iteration =48
# V_current = 1.9720209263119786e-09
# number of iteration =49
# V_current = 1.972018973852187e-09
# number of iteration =50
# V_current = 1.9732934898622897e-09
# number of iteration =51
# V_current = 1.974140330169834e-09
# number of iteration =52
# V_current = 1.970722386649763e-09
# number of iteration =53
# V_current = 1.9732709378004426e-09
# number of iteration =54
# V_current = 1.974112729342426e-09
# number of iteration =55
# V_current = 1.9723936744427454e-09
# number of iteration =56
# V_current = 1.9723788614640994e-09
# number of iteration =57
# V_current = 1.9736425762908416e-09
# number of iteration =58
# V_current = 1.974051525554647e-09
# number of iteration =59
# V_current = 1.971470824669031e-09
# number of iteration =60
# V_current = 1.973584288220625e-09
# number of iteration =61
# V_current = 1.973134759970595e-09
# number of iteration =62
# V_current = 1.9718293759349296e-09
# number of iteration =63
# V_current = 1.973085298788575e-09
# number of iteration =64
# V_current = 1.9739130187266027e-09
# number of iteration =65
# V_current = 1.9734576514052244e-09
# number of iteration =66
# V_current = 1.9730008263341927e-09
# number of iteration =67
# V_current = 1.9738250562217515e-09
# number of iteration =68
# V_current = 1.9725105166179257e-09
# number of iteration =69
# V_current = 1.9720496127126037e-09
# number of iteration =70
# V_current = 1.9745813247145363e-09
# number of iteration =71
# V_current = 1.972407222486306e-09
# number of iteration =72
# V_current = 1.9727983730510495e-09
# number of iteration =73
# V_current = 1.9723327625973366e-09
# number of iteration =74
# V_current = 1.971865969770532e-09
# number of iteration =75
# V_current = 1.9713980261830025e-09
# number of iteration =76
# V_current = 1.974353814365189e-09
# number of iteration =77
# V_current = 1.971743321520773e-09
# number of iteration =78
# V_current = 1.9734134684789837e-09
# number of iteration =79
# V_current = 1.973798317464341e-09
# number of iteration =80
# V_current = 1.9698988198696513e-09
# number of iteration =81
# V_current = 1.9728520725291004e-09
# number of iteration =82
# V_current = 1.9723775009933436e-09
# number of iteration =83
# V_current = 1.970187842865239e-09
# number of iteration =84
# V_current = 1.9697112006426765e-09
# number of iteration =85
# V_current = 1.971376957842204e-09
# number of iteration =86
# V_current = 1.9734711449804784e-09
# number of iteration =87
# V_current = 1.9712774875924276e-09
# number of iteration =88
# V_current = 1.9707978683511863e-09
# number of iteration =89
# V_current = 1.9716040972720846e-09
# number of iteration =90
# V_current = 1.9698362854027846e-09
# number of iteration =91
# V_current = 1.969783351597782e-09
# number of iteration =92
# V_current = 1.972733070999253e-09
# number of iteration =93
# V_current = 1.9713920078357587e-09
# number of iteration =94
# V_current = 1.971337475479228e-09
# number of iteration =95
# V_current = 1.970853182243045e-09
# number of iteration =96
# V_current = 1.9720852061274774e-09
# number of iteration =97
# V_current = 1.9698826609754363e-09
# number of iteration =98
# V_current = 1.9702551484575566e-09
# number of iteration =99
# V_current = 1.9710566169164657e-09
# number of iteration =100
# Iteration elapsed: 100
# Time elapsed:118.53 s
# Amount of highest displacement: 0.15 mikrometer
# V_current = 1.9705694839231505e-09
# number of iteration =101
# V_current = 1.971370226178882e-09
# number of iteration =102
# V_current = 1.9717411664823587e-09
# number of iteration =103
# V_current = 1.9716821797694533e-09
# number of iteration =104
# V_current = 1.970333913007726e-09
# number of iteration =105
# V_current = 1.969844282900497e-09
# number of iteration =106
# V_current = 1.9719323779690574e-09
# number of iteration =107
# V_current = 1.97187178064266e-09
# number of iteration =108
# V_current = 1.9692320771597893e-09
# number of iteration =109
# V_current = 1.9696003071824833e-09
# number of iteration =110
# V_current = 1.9712578717226503e-09
# number of iteration =111
# V_current = 1.9707658648097153e-09
# number of iteration =112
# V_current = 1.969843493118601e-09
# number of iteration =113
# V_current = 1.9689206401551454e-09
# number of iteration =114
# V_current = 1.9705774812246425e-09
# number of iteration =115
# V_current = 1.968793804507974e-09
# number of iteration =116
# V_current = 1.971310557140436e-09
# number of iteration =117
# V_current = 1.9695260770004775e-09
# number of iteration =118
# V_current = 1.969891907105632e-09
# number of iteration =119
# V_current = 1.9681064855540564e-09
# number of iteration =120
# V_current = 1.9697624985326523e-09
# number of iteration =121
# V_current = 1.970557979849358e-09
# number of iteration =122
# V_current = 1.968341145299495e-09
# number of iteration =123
# V_current = 1.968705838059735e-09
# number of iteration =124
# V_current = 1.9690703741753806e-09
# number of iteration =125
# V_current = 1.968143511108446e-09
# number of iteration =126
# V_current = 1.9693685523127467e-09
# number of iteration =127
# V_current = 1.9701631035007515e-09
# number of iteration =128
# V_current = 1.969666048614008e-09
# number of iteration =129
# V_current = 1.967877112072464e-09
# number of iteration =130
# V_current = 1.9678100434134504e-09
# number of iteration =131
# V_current = 1.970326424921424e-09
# number of iteration =132
# V_current = 1.9685366567401225e-09
# number of iteration =133
# V_current = 1.968038478750388e-09
# number of iteration =134
# V_current = 1.9705549309194847e-09
# number of iteration =135
# V_current = 1.9683336469223553e-09
# number of iteration =136
# V_current = 1.967404180345486e-09
# number of iteration =137
# V_current = 1.9677667921064672e-09
# number of iteration =138
# V_current = 1.968129324230425e-09
# number of iteration =139
# V_current = 1.9667684574807925e-09
# number of iteration =140
# V_current = 1.968854165242415e-09
# number of iteration =141
# V_current = 1.968354714577203e-09
# number of iteration =142
# V_current = 1.9674241867251924e-09
# number of iteration =143
# V_current = 1.9682171850727375e-09
# number of iteration =144
# V_current = 1.9668553781578486e-09
# number of iteration =145
# V_current = 1.9680792282059894e-09
# number of iteration =146
# V_current = 1.9680101002231817e-09
# number of iteration =147
# V_current = 1.969233977286769e-09
# number of iteration =148
# V_current = 1.967440508721472e-09
# number of iteration =149
# V_current = 1.967802166608942e-09
# number of iteration =150
# V_current = 1.9660082720696173e-09
# number of iteration =151
# V_current = 1.9680942502721744e-09
# number of iteration =152
# V_current = 1.966731191348979e-09
# number of iteration =153
# V_current = 1.9662302683405383e-09
# number of iteration =154
# V_current = 1.967454002562408e-09
# number of iteration =155
# V_current = 1.968246587277167e-09
# number of iteration =156
# V_current = 1.9694704291781583e-09
# number of iteration =157
# V_current = 1.9672442900504103e-09
# number of iteration =158
# V_current = 1.967605545403199e-09
# number of iteration =159
# V_current = 1.968829381176793e-09
# number of iteration =160
# V_current = 1.9678967024320222e-09
# number of iteration =161
# V_current = 1.966101222580199e-09
# number of iteration =162
# V_current = 1.966462320612828e-09
# number of iteration =163
# V_current = 1.9672547898020295e-09
# number of iteration =164
# V_current = 1.967615900483284e-09
# number of iteration =165
# V_current = 1.9653885337916936e-09
# number of iteration =166
# V_current = 1.9670438270747078e-09
# number of iteration =167
# V_current = 1.966541986411416e-09
# number of iteration =168
# V_current = 1.965608611225877e-09
# number of iteration =169
# V_current = 1.9672640454730367e-09
# number of iteration =170
# V_current = 1.9676250856223278e-09
# number of iteration =171
# V_current = 1.9662600567860444e-09
# number of iteration =172
# V_current = 1.9666210480573323e-09
# number of iteration =173
# V_current = 1.9674136045963795e-09
# number of iteration =174
# V_current = 1.96604835961969e-09
# number of iteration =175
# V_current = 1.965114584685849e-09
# number of iteration =176
# V_current = 1.9663387388798132e-09
# number of iteration =177
# V_current = 1.9666997388529043e-09
# number of iteration =178
# V_current = 1.9653342243680638e-09
# number of iteration =179
# V_current = 1.9669901462001177e-09
# number of iteration =180
# V_current = 1.96605619763754e-09
# number of iteration =181
# V_current = 1.9638271446075183e-09
# number of iteration =182
# V_current = 1.9650514846749803e-09
# number of iteration =183
# V_current = 1.9667076155415944e-09
# number of iteration =184
# V_current = 1.965341801384656e-09
# number of iteration =185
# V_current = 1.9652711085360876e-09
# number of iteration =186
# V_current = 1.963473412815923e-09
# number of iteration =187
# V_current = 1.9651297201651803e-09
# number of iteration =188
# V_current = 1.9646272493289874e-09
# number of iteration =189
# V_current = 1.9654201273079734e-09
# number of iteration =190
# V_current = 1.9662130616502807e-09
# number of iteration =191
# V_current = 1.9648469656862285e-09
# number of iteration =192
# V_current = 1.96520811832363e-09
# number of iteration =193
# V_current = 1.964273774270937e-09
# number of iteration =194
# V_current = 1.9637712428873937e-09
# number of iteration =195
# V_current = 1.9645642984414484e-09
# number of iteration =196
# V_current = 1.964925532483735e-09
# number of iteration =197
# V_current = 1.9644230171266475e-09
# number of iteration =198
# V_current = 1.963488585416176e-09
# number of iteration =199
# V_current = 1.9629860342691763e-09
# number of iteration =200
# Iteration elapsed: 200
# Time elapsed:230.37 s
# Amount of highest displacement: 0.06 mikrometer
# V_current = 1.9659388875609684e-09
# number of iteration =201
# V_current = 1.965004470364788e-09
# number of iteration =202
# V_current = 1.9636380726948576e-09
# number of iteration =203
# V_current = 1.9622716234646206e-09
# number of iteration =204
# V_current = 1.9630649810838232e-09
# number of iteration =205
# V_current = 1.9651543446535517e-09
# number of iteration =206
# V_current = 1.96421988325412e-09
# number of iteration =207
# V_current = 1.9632853972823005e-09
# number of iteration =208
# V_current = 1.964510955003727e-09
# number of iteration =209
# V_current = 1.962280404533003e-09
# number of iteration =210
# V_current = 1.9626419742531167e-09
# number of iteration =211
# V_current = 1.964299714466298e-09
# number of iteration =212
# V_current = 1.965093447115045e-09
# number of iteration =213
# V_current = 1.9632948621292745e-09
# number of iteration =214
# V_current = 1.9623603668394426e-09
# number of iteration =215
# V_current = 1.964018346093028e-09
# number of iteration =216
# V_current = 1.9630838765613963e-09
# number of iteration =217
# V_current = 1.9621493932725774e-09
# number of iteration =218
# V_current = 1.9633754422942142e-09
# number of iteration =219
# V_current = 1.962008861453852e-09
# number of iteration =220
# V_current = 1.963235011649399e-09
# number of iteration =221
# V_current = 1.961868427207772e-09
# number of iteration =222
# V_current = 1.9622303912967397e-09
# number of iteration =223
# V_current = 1.9625923976402145e-09
# number of iteration =224
# V_current = 1.9616579652540718e-09
# number of iteration =225
# V_current = 1.96331653705399e-09
# number of iteration =226
# V_current = 1.9636786700886064e-09
# number of iteration =227
# V_current = 1.9614477386502823e-09
# number of iteration =228
# V_current = 1.9626742936303593e-09
# number of iteration =229
# V_current = 1.9626043222950784e-09
# number of iteration =230
# V_current = 1.9612377555175754e-09
# number of iteration =231
# V_current = 1.961600031584696e-09
# number of iteration =232
# V_current = 1.962826795477836e-09
# number of iteration =233
# V_current = 1.962324712315985e-09
# number of iteration =234
# V_current = 1.9613904059764206e-09
# number of iteration =235
# V_current = 1.9617528318704607e-09
# number of iteration =236
# V_current = 1.9625475516603075e-09
# number of iteration =237
# V_current = 1.962045554224441e-09
# number of iteration =238
# V_current = 1.961543572167446e-09
# number of iteration =239
# V_current = 1.96147387738608e-09
# number of iteration =240
# V_current = 1.963997880352865e-09
# number of iteration =241
# V_current = 1.959605438330733e-09
# number of iteration =242
# V_current = 1.9608326798340366e-09
# number of iteration =243
# V_current = 1.9616276923823867e-09
# number of iteration =244
# V_current = 1.96026124233279e-09
# number of iteration =245
# V_current = 1.962353263254524e-09
# number of iteration =246
# V_current = 1.9614191649314262e-09
# number of iteration =247
# V_current = 1.9617820382413133e-09
# number of iteration =248
# V_current = 1.9604156432047613e-09
# number of iteration =249
# V_current = 1.9620755782502703e-09
# number of iteration =250
# V_current = 1.961573893975574e-09
# number of iteration =251
# V_current = 1.960207539341647e-09
# number of iteration =252
# V_current = 1.960138233467594e-09
# number of iteration =253
# V_current = 1.9600689587766083e-09
# number of iteration =254
# V_current = 1.962593883401611e-09
# number of iteration =255
# V_current = 1.960795236600691e-09
# number of iteration =256
# V_current = 1.9611584383486116e-09
# number of iteration =257
# V_current = 1.9602245504288426e-09
# number of iteration =258
# V_current = 1.9601554378187123e-09
# number of iteration =259
# V_current = 1.9613835184546997e-09
# number of iteration =260
# V_current = 1.9608820915568904e-09
# number of iteration =261
# V_current = 1.9612454804481554e-09
# number of iteration =262
# V_current = 1.9581496952109123e-09
# number of iteration =263
# V_current = 1.958945534868918e-09
# number of iteration =264
# V_current = 1.9614710704870442e-09
# number of iteration =265
# V_current = 1.959672533967832e-09
# number of iteration =266
# V_current = 1.9609009358739844e-09
# number of iteration =267
# V_current = 1.9595348467937678e-09
# number of iteration =268
# V_current = 1.959033621562586e-09
# number of iteration =269
# V_current = 1.9585324194721457e-09
# number of iteration =270
# V_current = 1.9575988027935262e-09
# number of iteration =271
# V_current = 1.9592598541029123e-09
# number of iteration =272
# V_current = 1.9570289540850177e-09
# number of iteration =273
# V_current = 1.9586900983845887e-09
# number of iteration =274
# V_current = 1.95818903506855e-09
# number of iteration =275
# V_current = 1.960282745757349e-09
# number of iteration =276
# V_current = 1.9584843672656187e-09
# number of iteration =277
# V_current = 1.957550921869458e-09
# number of iteration =278
# V_current = 1.9605097218189895e-09
# number of iteration =279
# V_current = 1.9582789230747657e-09
# number of iteration =280
# V_current = 1.959507937033831e-09
# number of iteration =281
# V_current = 1.9568446770538806e-09
# number of iteration =282
# V_current = 1.9580737654432767e-09
# number of iteration =283
# V_current = 1.9588704188608462e-09
# number of iteration =284
# V_current = 1.959667117767211e-09
# number of iteration =285
# V_current = 1.9570039044953434e-09
# number of iteration =286
# V_current = 1.956503172758778e-09
# number of iteration =287
# V_current = 1.9577324712946e-09
# number of iteration =288
# V_current = 1.9602593343633667e-09
# number of iteration =289
# V_current = 1.958461190606523e-09
# number of iteration =290
# V_current = 1.956663053204013e-09
# number of iteration =291
# V_current = 1.9583250332714623e-09
# number of iteration =292
# V_current = 1.9586895185442034e-09
# number of iteration =293
# V_current = 1.9564589223620132e-09
# number of iteration =294
# V_current = 1.957255987237805e-09
# number of iteration =295
# V_current = 1.9580530950371227e-09
# number of iteration =296
# V_current = 1.957985188669993e-09
# number of iteration =297
# V_current = 1.957052251207898e-09
# number of iteration =298
# V_current = 1.9574169356041803e-09
# number of iteration =299
# V_current = 1.9577816565388817e-09
# number of iteration =300
# Iteration elapsed: 300
# Time elapsed:342.20 s
# Amount of highest displacement: 0.05 mikrometer
# V_current = 1.9564162571904778e-09
# number of iteration =301
# V_current = 1.9580786655380728e-09
# number of iteration =302
# V_current = 1.9571458596206e-09
# number of iteration =303
# V_current = 1.9570781681316942e-09
# number of iteration =304
# V_current = 1.9570105075445897e-09
# number of iteration =305
# V_current = 1.955645222992547e-09
# number of iteration =306
# V_current = 1.957307832828235e-09
# number of iteration =307
# V_current = 1.9555100418433606e-09
# number of iteration =308
# V_current = 1.9554424975215105e-09
# number of iteration =309
# V_current = 1.9558075447347648e-09
# number of iteration =310
# V_current = 1.9570377529494607e-09
# number of iteration =311
# V_current = 1.9565377442105005e-09
# number of iteration =312
# V_current = 1.9564703288976313e-09
# number of iteration =313
# V_current = 1.9577006518232403e-09
# number of iteration =314
# V_current = 1.9546053042240093e-09
# number of iteration =315
# V_current = 1.9558356918747624e-09
# number of iteration =316
# V_current = 1.9553358206558272e-09
# number of iteration =317
# V_current = 1.9574314386677997e-09
# number of iteration =318
# V_current = 1.9543361574561e-09
# number of iteration =319
# V_current = 1.9559992697740785e-09
# number of iteration =320
# V_current = 1.9572298439415586e-09
# number of iteration =321
# V_current = 1.9558649522470095e-09
# number of iteration =322
# V_current = 1.9545000799926995e-09
# number of iteration =323
# V_current = 1.955298166386256e-09
# number of iteration =324
# V_current = 1.956961468080596e-09
# number of iteration =325
# V_current = 1.955596675056513e-09
# number of iteration =326
# V_current = 1.9555296799481726e-09
# number of iteration =327
# V_current = 1.9563279027092417e-09
# number of iteration =328
# V_current = 1.9540979913187683e-09
# number of iteration =329
# V_current = 1.9557614687999586e-09
# number of iteration =330
# V_current = 1.956127191516242e-09
# number of iteration =331
# V_current = 1.955627746344431e-09
# number of iteration =332
# V_current = 1.9525327195098237e-09
# number of iteration =333
# V_current = 1.9559267433545998e-09
# number of iteration =334
# V_current = 1.9554273814648108e-09
# number of iteration =335
# V_current = 1.954062835477667e-09
# number of iteration =336
# V_current = 1.954861343494038e-09
# number of iteration =337
# V_current = 1.9543620621820565e-09
# number of iteration =338
# V_current = 1.9547280251287644e-09
# number of iteration =339
# V_current = 1.955526629205e-09
# number of iteration =340
# V_current = 1.9537295995617476e-09
# number of iteration =341
# V_current = 1.9553934876849434e-09
# number of iteration =342
# V_current = 1.9535965065841663e-09
# number of iteration =343
# V_current = 1.9530973886744095e-09
# number of iteration =344
# V_current = 1.9543287585072662e-09
# number of iteration =345
# V_current = 1.9551275463304917e-09
# number of iteration =346
# V_current = 1.9546285145891857e-09
# number of iteration =347
# V_current = 1.9523990367591703e-09
# number of iteration =348
# V_current = 1.9553610062415927e-09
# number of iteration =349
# V_current = 1.9535641975567956e-09
# number of iteration =350
# V_current = 1.9539305136065134e-09
# number of iteration =351
# V_current = 1.954296859263352e-09
# number of iteration =352
# V_current = 1.9550958566122133e-09
# number of iteration =353
# V_current = 1.9550296388081982e-09
# number of iteration =354
# V_current = 1.954530825029838e-09
# number of iteration =355
# V_current = 1.95403203752598e-09
# number of iteration =356
# V_current = 1.9535332763118247e-09
# number of iteration =357
# V_current = 1.952601915732925e-09
# number of iteration =358
# V_current = 1.952103206532007e-09
# number of iteration =359
# V_current = 1.9546329117053464e-09
# number of iteration =360
# V_current = 1.9528363768769466e-09
# number of iteration =361
# V_current = 1.9527703768538137e-09
# number of iteration =362
# V_current = 1.9557328033218547e-09
# number of iteration =363
# V_current = 1.953071087586276e-09
# number of iteration =364
# V_current = 1.953870428523557e-09
# number of iteration =365
# V_current = 1.9538045386218377e-09
# number of iteration =366
# V_current = 1.9541713059305426e-09
# number of iteration =367
# V_current = 1.95237494780797e-09
# number of iteration =368
# V_current = 1.951443875585463e-09
# number of iteration =369
# V_current = 1.9535412481173384e-09
# number of iteration =370
# V_current = 1.951312334272285e-09
# number of iteration =371
# V_current = 1.9516792357376574e-09
# number of iteration =372
# V_current = 1.9516135322558587e-09
# number of iteration =373
# V_current = 1.952413120284677e-09
# number of iteration =374
# V_current = 1.9523474704395343e-09
# number of iteration =375
# V_current = 1.9527144799178114e-09
# number of iteration =376
# V_current = 1.951350983964669e-09
# number of iteration =377
# V_current = 1.95215067939575e-09
# number of iteration =378
# V_current = 1.9525177683449952e-09
# number of iteration =379
# V_current = 1.9520196168266486e-09
# number of iteration =380
# V_current = 1.9523867583419063e-09
# number of iteration =381
# V_current = 1.951023391619567e-09
# number of iteration =382
# V_current = 1.951390585271479e-09
# number of iteration =383
# V_current = 1.950892537596238e-09
# number of iteration =384
# V_current = 1.9499618821229126e-09
# number of iteration =385
# V_current = 1.9511944210607595e-09
# number of iteration =386
# V_current = 1.9511290846848227e-09
# number of iteration =387
# V_current = 1.951929041281886e-09
# number of iteration =388
# V_current = 1.9505658555738223e-09
# number of iteration =389
# V_current = 1.9513658632529405e-09
# number of iteration =390
# V_current = 1.950867996059296e-09
# number of iteration =391
# V_current = 1.9503701546167765e-09
# number of iteration =392
# V_current = 1.9533334034045544e-09
# number of iteration =393
# V_current = 1.9519703463306338e-09
# number of iteration =394
# V_current = 1.951039948306562e-09
# number of iteration =395
# V_current = 1.949676943829868e-09
# number of iteration =396
# V_current = 1.949179230448585e-09
# number of iteration =397
# V_current = 1.949546806811776e-09
# number of iteration =398
# V_current = 1.9499144078107742e-09
# number of iteration =399
# V_current = 1.949416770356709e-09
# number of iteration =400
# Iteration elapsed: 400
# Time elapsed:453.95 s
# Amount of highest displacement: 0.05 mikrometer
# V_current = 1.9506496832687766e-09
# number of iteration =401
# V_current = 1.9510173575061344e-09
# number of iteration =402
# V_current = 1.949654533769604e-09
# number of iteration =403
# V_current = 1.949589627496346e-09
# number of iteration =404
# V_current = 1.9525531547608045e-09
# number of iteration =405
# V_current = 1.949892518677162e-09
# number of iteration =406
# V_current = 1.9506929442476062e-09
# number of iteration =407
# V_current = 1.9497628782818173e-09
# number of iteration =408
# V_current = 1.9505633512804232e-09
# number of iteration =409
# V_current = 1.9487680806128707e-09
# number of iteration =410
# V_current = 1.9487033471201963e-09
# number of iteration =411
# V_current = 1.950801771872898e-09
# number of iteration =412
# V_current = 1.949006579581508e-09
# number of iteration =413
# V_current = 1.9493745443884606e-09
# number of iteration =414
# V_current = 1.951040407985461e-09
# number of iteration =415
# V_current = 1.949245294075407e-09
# number of iteration =416
# V_current = 1.948748081021947e-09
# number of iteration =417
# V_current = 1.949116140207558e-09
# number of iteration =418
# V_current = 1.9477537305815914e-09
# number of iteration =419
# V_current = 1.9494197046570397e-09
# number of iteration =420
# V_current = 1.949787832647706e-09
# number of iteration =421
# V_current = 1.9488581201201593e-09
# number of iteration =422
# V_current = 1.9479284339985056e-09
# number of iteration =423
# V_current = 1.9491618727523196e-09
# number of iteration =424
# V_current = 1.9482322361094102e-09
# number of iteration =425
# V_current = 1.948600480788394e-09
# number of iteration =426
# V_current = 1.9489687476356036e-09
# number of iteration =427
# V_current = 1.9493370365565318e-09
# number of iteration =428
# V_current = 1.9497053474573465e-09
# number of iteration =429
# V_current = 1.9492084495888388e-09
# number of iteration =430
# V_current = 1.948278962070765e-09
# number of iteration =431
# V_current = 1.948214728549608e-09
# number of iteration =432
# V_current = 1.9494483571850823e-09
# number of iteration =433
# V_current = 1.948951555604145e-09
# number of iteration =434
# V_current = 1.947589556233545e-09
# number of iteration =435
# V_current = 1.9483906373426472e-09
# number of iteration =436
# V_current = 1.9478939093301605e-09
# number of iteration =437
# V_current = 1.9486950322672037e-09
# number of iteration =438
# V_current = 1.948630958982787e-09
# number of iteration =439
# V_current = 1.949432122493023e-09
# number of iteration =440
# V_current = 1.9480702751165923e-09
# number of iteration =441
# V_current = 1.947573666293508e-09
# number of iteration =442
# V_current = 1.9479422904549202e-09
# number of iteration =443
# V_current = 1.9465805226629983e-09
# number of iteration =444
# V_current = 1.946516590075441e-09
# number of iteration =445
# V_current = 1.9464526801805148e-09
# number of iteration =446
# V_current = 1.9481191939987793e-09
# number of iteration =447
# V_current = 1.9450271304927694e-09
# number of iteration =448
# V_current = 1.946693684432576e-09
# number of iteration =449
# V_current = 1.9466298638147863e-09
# number of iteration =450
# V_current = 1.9469986618232457e-09
# number of iteration =451
# V_current = 1.946934885004665e-09
# number of iteration =452
# V_current = 1.9477363186494927e-09
# number of iteration =453
# V_current = 1.948105177304252e-09
# number of iteration =454
# V_current = 1.9454459127687256e-09
# number of iteration =455
# V_current = 1.9471125915308587e-09
# number of iteration =456
# V_current = 1.9474815145579342e-09
# number of iteration =457
# V_current = 1.9487156345517156e-09
# number of iteration =458
# V_current = 1.9456238956197914e-09
# number of iteration =459
# V_current = 1.9481558162236327e-09
# number of iteration =460
# V_current = 1.9459293087325522e-09
# number of iteration =461
# V_current = 1.9462983384789276e-09
# number of iteration =462
# V_current = 1.9470999705317987e-09
# number of iteration =463
# V_current = 1.947036456548413e-09
# number of iteration =464
# V_current = 1.9482707054320175e-09
# number of iteration =465
# V_current = 1.945179177363683e-09
# number of iteration =466
# V_current = 1.945548311463443e-09
# number of iteration =467
# V_current = 1.945917464800578e-09
# number of iteration =468
# V_current = 1.946286637300156e-09
# number of iteration =469
# V_current = 1.946223254719922e-09
# number of iteration =470
# V_current = 1.946592466591993e-09
# number of iteration =471
# V_current = 1.947826840648423e-09
# number of iteration =472
# V_current = 1.945168095492357e-09
# number of iteration =473
# V_current = 1.94467223246477e-09
# number of iteration =474
# V_current = 1.9450415288937433e-09
# number of iteration =475
# V_current = 1.945410844057276e-09
# number of iteration =476
# V_current = 1.9457801778836525e-09
# number of iteration =477
# V_current = 1.947879785142457e-09
# number of iteration =478
# V_current = 1.946951463596723e-09
# number of iteration =479
# V_current = 1.945158046659397e-09
# number of iteration =480
# V_current = 1.9450949003063863e-09
# number of iteration =481
# V_current = 1.945896891541345e-09
# number of iteration =482
# V_current = 1.943671000395821e-09
# number of iteration =483
# V_current = 1.945338143239811e-09
# number of iteration =484
# V_current = 1.9461401877589025e-09
# number of iteration =485
# V_current = 1.9452120371373485e-09
# number of iteration =486
# V_current = 1.9451490154756143e-09
# number of iteration =487
# V_current = 1.9455185644128468e-09
# number of iteration =488
# V_current = 1.94545558301011e-09
# number of iteration =489
# V_current = 1.942797341534729e-09
# number of iteration =490
# V_current = 1.944032046515441e-09
# number of iteration =491
# V_current = 1.9444016756649595e-09
# number of iteration =492
# V_current = 1.9456364072750378e-09
# number of iteration =493
# V_current = 1.944708446199002e-09
# number of iteration =494
# V_current = 1.9433479723862727e-09
# number of iteration =495
# V_current = 1.9437176796252673e-09
# number of iteration =496
# V_current = 1.9436548680564415e-09
# number of iteration =497
# V_current = 1.9431595422225315e-09
# number of iteration =498
# V_current = 1.943529306430757e-09
# number of iteration =499
# V_current = 1.946061746399269e-09
# number of iteration =500
# Iteration elapsed: 500
# Time elapsed:566.31 s
# Amount of highest displacement: 0.05 mikrometer
# V_current = 1.9421062362138494e-09
# number of iteration =501
# V_current = 1.943341117221458e-09
# number of iteration =502
# V_current = 1.9450085360781198e-09
# number of iteration =503
# V_current = 1.9440808102381902e-09
# number of iteration =504
# V_current = 1.9444506823645735e-09
# number of iteration =505
# V_current = 1.9448205714874322e-09
# number of iteration =506
# V_current = 1.944757956982965e-09
# number of iteration =507
# V_current = 1.9429652868409764e-09
# number of iteration =508
# V_current = 1.9442002709929304e-09
# number of iteration =509
# V_current = 1.9441377183852624e-09
# number of iteration =510
# V_current = 1.9423451297229847e-09
# number of iteration =511
# V_current = 1.9422826237555143e-09
# number of iteration =512
# V_current = 1.9443826912669144e-09
# number of iteration =513
# V_current = 1.945617743950483e-09
# number of iteration =514
# V_current = 1.9420952256426956e-09
# number of iteration =515
# V_current = 1.9424653050745375e-09
# number of iteration =516
# V_current = 1.943700408875868e-09
# number of iteration =517
# V_current = 1.9423405087438168e-09
# number of iteration =518
# V_current = 1.9444406429474814e-09
# number of iteration =519
# V_current = 1.9426482903283503e-09
# number of iteration =520
# V_current = 1.943883450823064e-09
# number of iteration =521
# V_current = 1.941658657758998e-09
# number of iteration =522
# V_current = 1.9420288633858356e-09
# number of iteration =523
# V_current = 1.9428315769755138e-09
# number of iteration =524
# V_current = 1.9419043427288812e-09
# number of iteration =525
# V_current = 1.9440045533514845e-09
# number of iteration =526
# V_current = 1.9426448733369047e-09
# number of iteration =527
# V_current = 1.9443126168190728e-09
# number of iteration =528
# V_current = 1.94338546755558e-09
# number of iteration =529
# V_current = 1.942890826028499e-09
# number of iteration =530
# V_current = 1.94412612494629e-09
# number of iteration =531
# V_current = 1.9410366567328626e-09
# number of iteration =532
# V_current = 1.9414070391762727e-09
# number of iteration =533
# V_current = 1.9430748589842955e-09
# number of iteration =534
# V_current = 1.9451751554388194e-09
# number of iteration =535
# V_current = 1.940355928946389e-09
# number of iteration =536
# V_current = 1.940726382860624e-09
# number of iteration =537
# V_current = 1.942394251812398e-09
# number of iteration =538
# V_current = 1.942332266339021e-09
# number of iteration =539
# V_current = 1.940540448774967e-09
# number of iteration =540
# V_current = 1.941775891672932e-09
# number of iteration =541
# V_current = 1.9421464242458235e-09
# number of iteration =542
# V_current = 1.9399222292050636e-09
# number of iteration =543
# V_current = 1.942455079721435e-09
# number of iteration =544
# V_current = 1.940663393005088e-09
# number of iteration =545
# V_current = 1.9406015461529895e-09
# number of iteration =546
# V_current = 1.940972167683824e-09
# number of iteration =547
# V_current = 1.9435050420846423e-09
# number of iteration =548
# V_current = 1.942145901337717e-09
# number of iteration =549
# V_current = 1.9394894598710156e-09
# number of iteration =550
# V_current = 1.9398601527820284e-09
# number of iteration =551
# V_current = 1.9410957401384625e-09
# number of iteration =552
# V_current = 1.9397367073941625e-09
# number of iteration =553
# V_current = 1.9396750127378474e-09
# number of iteration =554
# V_current = 1.940910638445066e-09
# number of iteration =555
# V_current = 1.943011134749622e-09
# number of iteration =556
# V_current = 1.9416521902630495e-09
# number of iteration =557
# V_current = 1.938563564456903e-09
# number of iteration =558
# V_current = 1.941096522460663e-09
# number of iteration =559
# V_current = 1.9384403876080162e-09
# number of iteration =560
# V_current = 1.9392436708010376e-09
# number of iteration =561
# V_current = 1.9400469643882674e-09
# number of iteration =562
# V_current = 1.941282686194528e-09
# number of iteration =563
# V_current = 1.939923919038689e-09
# number of iteration =564
# V_current = 1.9394300100853494e-09
# number of iteration =565
# V_current = 1.938071299979226e-09
# number of iteration =566
# V_current = 1.939307078871285e-09
# number of iteration =567
# V_current = 1.939245640694234e-09
# number of iteration =568
# V_current = 1.9417786544766066e-09
# number of iteration =569
# V_current = 1.9395552226136377e-09
# number of iteration =570
# V_current = 1.938629034073516e-09
# number of iteration =571
# V_current = 1.940297268409645e-09
# number of iteration =572
# V_current = 1.9406683122687647e-09
# number of iteration =573
# V_current = 1.937580208246317e-09
# number of iteration =574
# V_current = 1.9388160829178127e-09
# number of iteration =575
# V_current = 1.9387547899754338e-09
# number of iteration =576
# V_current = 1.9417202374860972e-09
# number of iteration =577
# V_current = 1.9381998713593318e-09
# number of iteration =578
# V_current = 1.9403005579713458e-09
# number of iteration =579
# V_current = 1.940671711055625e-09
# number of iteration =580
# V_current = 1.9384485952238004e-09
# number of iteration =581
# V_current = 1.9396845449477155e-09
# number of iteration =582
# V_current = 1.940920499689582e-09
# number of iteration =583
# V_current = 1.940426963380369e-09
# number of iteration =584
# V_current = 1.938203961791536e-09
# number of iteration =585
# V_current = 1.9390075873582892e-09
# number of iteration =586
# V_current = 1.9398112220351346e-09
# number of iteration =587
# V_current = 1.937588308322528e-09
# number of iteration =588
# V_current = 1.938391976276494e-09
# number of iteration =589
# V_current = 1.939628014194029e-09
# number of iteration =590
# V_current = 1.9391346214370853e-09
# number of iteration =591
# V_current = 1.9382088940755576e-09
# number of iteration =592
# V_current = 1.937283193107611e-09
# number of iteration =593
# V_current = 1.9402486884296116e-09
# number of iteration =594
# V_current = 1.937161270386163e-09
# number of iteration =595
# V_current = 1.9375326831475657e-09
# number of iteration =596
# V_current = 1.941362873537298e-09
# number of iteration =597
# V_current = 1.940004921257687e-09
# number of iteration =598
# V_current = 1.9386469997784914e-09
# number of iteration =599
# V_current = 1.9372891091223907e-09
# number of iteration =600
# Iteration elapsed: 600
# Time elapsed:678.43 s
# Amount of highest displacement: 0.05 mikrometer
# V_current = 1.9376605958648136e-09
# number of iteration =601
# V_current = 1.9367350923332444e-09
# number of iteration =602
# V_current = 1.9371066115965013e-09
# number of iteration =603
# V_current = 1.937045813813742e-09
# number of iteration =604
# V_current = 1.9378496886050066e-09
# number of iteration =605
# V_current = 1.9369242701921116e-09
# number of iteration =606
# V_current = 1.936863524305263e-09
# number of iteration =607
# V_current = 1.9380997581077846e-09
# number of iteration =608
# V_current = 1.936309765728343e-09
# number of iteration =609
# V_current = 1.9362490738086473e-09
# number of iteration =610
# V_current = 1.9374853409383256e-09
# number of iteration =611
# V_current = 1.9378569881357353e-09
# number of iteration =612
# V_current = 1.93693171977985e-09
# number of iteration =613
# V_current = 1.9360064777415528e-09
# number of iteration =614
# V_current = 1.9381073952199388e-09
# number of iteration =615
# V_current = 1.9363175847738166e-09
# number of iteration =616
# V_current = 1.93755391065341e-09
# number of iteration =617
# V_current = 1.9379256440371395e-09
# number of iteration =618
# V_current = 1.937000503387041e-09
# number of iteration =619
# V_current = 1.9360753890274123e-09
# number of iteration =620
# V_current = 1.936014882518299e-09
# number of iteration =621
# V_current = 1.936818969800654e-09
# number of iteration =622
# V_current = 1.937623064590541e-09
# number of iteration =623
# V_current = 1.936265748183875e-09
# number of iteration =624
# V_current = 1.936637588255436e-09
# number of iteration =625
# V_current = 1.937009440432146e-09
# number of iteration =626
# V_current = 1.9356521981086692e-09
# number of iteration =627
# V_current = 1.9355918096051854e-09
# number of iteration =628
# V_current = 1.93769279733861e-09
# number of iteration =629
# V_current = 1.935903352394579e-09
# number of iteration =630
# V_current = 1.9354107446184145e-09
# number of iteration =631
# V_current = 1.9370794820035227e-09
# number of iteration =632
# V_current = 1.9352901181770436e-09
# number of iteration =633
# V_current = 1.9369588697261044e-09
# number of iteration =634
# V_current = 1.935169558371637e-09
# number of iteration =635
# V_current = 1.9368383239264064e-09
# number of iteration =636
# V_current = 1.9333200541556716e-09
# number of iteration =637
# V_current = 1.9367178444321824e-09
# number of iteration =638
# V_current = 1.9357931337361247e-09
# number of iteration =639
# V_current = 1.9353006947094793e-09
# number of iteration =640
# V_current = 1.935672763091211e-09
# number of iteration =641
# V_current = 1.9343158807276586e-09
# number of iteration =642
# V_current = 1.9364169346632903e-09
# number of iteration =643
# V_current = 1.9346278592445988e-09
# number of iteration =644
# V_current = 1.934999986115735e-09
# number of iteration =645
# V_current = 1.934939893677561e-09
# number of iteration =646
# V_current = 1.9357442743248704e-09
# number of iteration =647
# V_current = 1.9356842097021468e-09
# number of iteration =648
# V_current = 1.9338952676893776e-09
# number of iteration =649
# V_current = 1.93599635038191e-09
# number of iteration =650
# V_current = 1.9342074582548213e-09
# number of iteration =651
# V_current = 1.9354441142876365e-09
# number of iteration =652
# V_current = 1.936248558163046e-09
# number of iteration =653
# V_current = 1.935756375185818e-09
# number of iteration =654
# V_current = 1.932670962040555e-09
# number of iteration =655
# V_current = 1.934772072749888e-09
# number of iteration =656
# V_current = 1.934712156842342e-09
# number of iteration =657
# V_current = 1.934220056018329e-09
# number of iteration =658
# V_current = 1.9341601748945964e-09
# number of iteration =659
# V_current = 1.9353968980379565e-09
# number of iteration =660
# V_current = 1.9336082674293037e-09
# number of iteration =661
# V_current = 1.9339806281239615e-09
# number of iteration =662
# V_current = 1.9330564343354095e-09
# number of iteration =663
# V_current = 1.9360219404508987e-09
# number of iteration =664
# V_current = 1.9333690423929055e-09
# number of iteration =665
# V_current = 1.9350379998289156e-09
# number of iteration =666
# V_current = 1.9328173475708418e-09
# number of iteration =667
# V_current = 1.9349184950103888e-09
# number of iteration =668
# V_current = 1.9331300733386916e-09
# number of iteration =669
# V_current = 1.9330703709261743e-09
# number of iteration =670
# V_current = 1.933010684415394e-09
# number of iteration =671
# V_current = 1.9333831794199035e-09
# number of iteration =672
# V_current = 1.9337556851677566e-09
# number of iteration =673
# V_current = 1.935424683155394e-09
# number of iteration =674
# V_current = 1.933636412888845e-09
# number of iteration =675
# V_current = 1.9327124897167615e-09
# number of iteration =676
# V_current = 1.9322207454197843e-09
# number of iteration =677
# V_current = 1.933457622913496e-09
# number of iteration =678
# V_current = 1.9325337624971825e-09
# number of iteration =679
# V_current = 1.932474218244042e-09
# number of iteration =680
# V_current = 1.933278974617952e-09
# number of iteration =681
# V_current = 1.9336515964471256e-09
# number of iteration =682
# V_current = 1.9327278169497082e-09
# number of iteration =683
# V_current = 1.9339647368296502e-09
# number of iteration =684
# V_current = 1.934337392594455e-09
# number of iteration =685
# V_current = 1.932117282030499e-09
# number of iteration =686
# V_current = 1.9324899742143693e-09
# number of iteration =687
# V_current = 1.9332948009762137e-09
# number of iteration =688
# V_current = 1.9345317544302533e-09
# number of iteration =689
# V_current = 1.932311755810454e-09
# number of iteration =690
# V_current = 1.933548729824517e-09
# number of iteration =691
# V_current = 1.933057248653093e-09
# number of iteration =692
# V_current = 1.9312694549394006e-09
# number of iteration =693
# V_current = 1.9320743485362556e-09
# number of iteration =694
# V_current = 1.9307187179383977e-09
# number of iteration =695
# V_current = 1.931955737688714e-09
# number of iteration =696
# V_current = 1.9318964553998657e-09
# number of iteration =697
# V_current = 1.931837188510661e-09
# number of iteration =698
# V_current = 1.932642127450774e-09
# number of iteration =699
# V_current = 1.9325828859930583e-09
# number of iteration =700
# Iteration elapsed: 700
# Time elapsed:791.04 s
# Amount of highest displacement: 0.05 mikrometer
# V_current = 1.93036321034786e-09
# number of iteration =701
# V_current = 1.9316002745974198e-09
# number of iteration =702
# V_current = 1.933269422736979e-09
# number of iteration =703
# V_current = 1.9301856638735293e-09
# number of iteration =704
# V_current = 1.931422749997896e-09
# number of iteration =705
# V_current = 1.930931529123275e-09
# number of iteration =706
# V_current = 1.9308724027227977e-09
# number of iteration =707
# V_current = 1.9321095051066046e-09
# number of iteration =708
# V_current = 1.932482469580637e-09
# number of iteration =709
# V_current = 1.9341516412767825e-09
# number of iteration =710
# V_current = 1.9302039861231174e-09
# number of iteration =711
# V_current = 1.9327373008803618e-09
# number of iteration =712
# V_current = 1.930517963521337e-09
# number of iteration =713
# V_current = 1.9304589433622892e-09
# number of iteration =714
# V_current = 1.931696095220256e-09
# number of iteration =715
# V_current = 1.9329332459076084e-09
# number of iteration =716
# V_current = 1.930281973474934e-09
# number of iteration =717
# V_current = 1.93022301365319e-09
# number of iteration =718
# V_current = 1.931460193197069e-09
# number of iteration =719
# V_current = 1.930969216556013e-09
# number of iteration =720
# V_current = 1.9287501164032534e-09
# number of iteration =721
# V_current = 1.9312834244099318e-09
# number of iteration =722
# V_current = 1.930792500908004e-09
# number of iteration =723
# V_current = 1.9311656534138136e-09
# number of iteration =724
# V_current = 1.9298107151645444e-09
# number of iteration =725
# V_current = 1.930183897531728e-09
# number of iteration =726
# V_current = 1.9301250697531925e-09
# number of iteration =727
# V_current = 1.9296342400486642e-09
# number of iteration =728
# V_current = 1.930439472920775e-09
# number of iteration =729
# V_current = 1.931244709636959e-09
# number of iteration =730
# V_current = 1.932913967270498e-09
# number of iteration =731
# V_current = 1.929399148118181e-09
# number of iteration =732
# V_current = 1.929340412211077e-09
# number of iteration =733
# V_current = 1.93014569162768e-09
# number of iteration =734
# V_current = 1.9300869797615653e-09
# number of iteration =735
# V_current = 1.929596287935652e-09
# number of iteration =736
# V_current = 1.930401592239212e-09
# number of iteration =737
# V_current = 1.929478943496815e-09
# number of iteration =738
# V_current = 1.9281243342074937e-09
# number of iteration =739
# V_current = 1.9310895923195685e-09
# number of iteration =740
# V_current = 1.9305989796051296e-09
# number of iteration =741
# V_current = 1.928380475045037e-09
# number of iteration =742
# V_current = 1.928321889202653e-09
# number of iteration =743
# V_current = 1.9286952904353117e-09
# number of iteration =744
# V_current = 1.930364609592992e-09
# number of iteration =745
# V_current = 1.930306053624771e-09
# number of iteration =746
# V_current = 1.928951620166701e-09
# number of iteration =747
# V_current = 1.9293250629899038e-09
# number of iteration =748
# V_current = 1.9275387227254855e-09
# number of iteration =749
# V_current = 1.929208064247386e-09
# number of iteration =750
# V_current = 1.927853728350509e-09
# number of iteration =751
# V_current = 1.929955023527581e-09
# number of iteration =752
# V_current = 1.927736833655213e-09
# number of iteration =753
# V_current = 1.9285422966678865e-09
# number of iteration =754
# V_current = 1.928915821364566e-09
# number of iteration =755
# V_current = 1.9279935389066754e-09
# number of iteration =756
# V_current = 1.9283670896682577e-09
# number of iteration =757
# V_current = 1.92874064918541e-09
# number of iteration =758
# V_current = 1.929978077715917e-09
# number of iteration =759
# V_current = 1.9277600851989934e-09
# number of iteration =760
# V_current = 1.928565606676339e-09
# number of iteration =761
# V_current = 1.928507287919774e-09
# number of iteration =762
# V_current = 1.9262893897290954e-09
# number of iteration =763
# V_current = 1.9288226093416794e-09
# number of iteration =764
# V_current = 1.9283324176834237e-09
# number of iteration =765
# V_current = 1.9300017969932344e-09
# number of iteration =766
# V_current = 1.927352094416271e-09
# number of iteration =767
# V_current = 1.928157676190268e-09
# number of iteration =768
# V_current = 1.9280994575676598e-09
# number of iteration =769
# V_current = 1.926745557002154e-09
# number of iteration =770
# V_current = 1.9292787506229536e-09
# number of iteration =771
# V_current = 1.9287886730906396e-09
# number of iteration =772
# V_current = 1.929594285828628e-09
# number of iteration =773
# V_current = 1.9256491417328186e-09
# number of iteration =774
# V_current = 1.9273185601668098e-09
# number of iteration =775
# V_current = 1.9272604438555117e-09
# number of iteration =776
# V_current = 1.9280660988387285e-09
# number of iteration =777
# V_current = 1.925848626619636e-09
# number of iteration =778
# V_current = 1.927518052551208e-09
# number of iteration =779
# V_current = 1.928323729646379e-09
# number of iteration =780
# V_current = 1.9269700742576844e-09
# number of iteration =781
# V_current = 1.9251845862468927e-09
# number of iteration =782
# V_current = 1.9285814698425546e-09
# number of iteration =783
# V_current = 1.9276597381351437e-09
# number of iteration =784
# V_current = 1.926306176707856e-09
# number of iteration =785
# V_current = 1.925384499231595e-09
# number of iteration =786
# V_current = 1.9266220951981797e-09
# number of iteration =787
# V_current = 1.925268607834604e-09
# number of iteration =788
# V_current = 1.926938058014151e-09
# number of iteration =789
# V_current = 1.9273119764009493e-09
# number of iteration =790
# V_current = 1.9263903892603395e-09
# number of iteration =791
# V_current = 1.9263324976627105e-09
# number of iteration =792
# V_current = 1.9267064520163768e-09
# number of iteration =793
# V_current = 1.9279440726089264e-09
# ...
# number of iteration =1498
# V_current = 1.888322267659098e-09
# number of iteration =1499
# V_current = 1.8891308403974372e-09
# number of iteration =1500
# Iteration elapsed: 1500
# Time elapsed:1688.33 s
# Amount of highest displacement: 0.05 mikrometer
# V_current = 1.890368800072183e-09
# number of iteration =1501
# V_current = 1.8868834619433907e-09
# number of iteration =1502
# V_current = 1.8881214353623545e-09
# number of iteration =1503
# V_current = 1.8897887768982595e-09
# number of iteration =1504
# V_current = 1.8880210717086783e-09
# number of iteration =1505
# V_current = 1.886682779760618e-09
# number of iteration =1506
# V_current = 1.8870620017126726e-09
# number of iteration =1507
# V_current = 1.889588059294264e-09
# number of iteration =1508
# V_current = 1.8873910861074437e-09
# number of iteration =1509
# V_current = 1.886052877996015e-09
# number of iteration =1510
# V_current = 1.8881495459297794e-09
# number of iteration =1511
# V_current = 1.8868113703110833e-09
# number of iteration =1512
# V_current = 1.8876199663027663e-09
# number of iteration =1513
# V_current = 1.8892872445256233e-09
# number of iteration =1514
# V_current = 1.8888077986757628e-09
# number of iteration =1515
# V_current = 1.8878990322963734e-09
# number of iteration =1516
# V_current = 1.8869902896816006e-09
# number of iteration =1517
# V_current = 1.8873695585017567e-09
# number of iteration =1518
# V_current = 1.8868901775611856e-09
# number of iteration =1519
# V_current = 1.887269456211674e-09
# number of iteration =1520
# V_current = 1.8863607822567425e-09
# number of iteration =1521
# V_current = 1.888457331064907e-09
# number of iteration =1522
# V_current = 1.8871193678521998e-09
# number of iteration =1523
# V_current = 1.8874986623370253e-09
# number of iteration =1524
# V_current = 1.8887365635948614e-09
# number of iteration =1525
# V_current = 1.8878279555979376e-09
# number of iteration =1526
# V_current = 1.886919371347391e-09
# number of iteration =1527
# V_current = 1.887298685364064e-09
# number of iteration =1528
# V_current = 1.888107288210268e-09
# number of iteration =1529
# V_current = 1.884623045024747e-09
# number of iteration =1530
# V_current = 1.886290233066468e-09
# number of iteration =1531
# V_current = 1.8866695703194253e-09
# number of iteration =1532
# V_current = 1.8866196360214894e-09
# number of iteration =1533
# V_current = 1.8882867857541885e-09
# number of iteration =1534
# V_current = 1.886949058374936e-09
# number of iteration =1535
# V_current = 1.8873284074615197e-09
# number of iteration =1536
# V_current = 1.886419985057862e-09
# number of iteration =1537
# V_current = 1.8863700938544157e-09
# number of iteration =1538
# V_current = 1.8888957109935644e-09
# number of iteration =1539
# V_current = 1.885841091089877e-09
# number of iteration =1540
# V_current = 1.886220471871538e-09
# number of iteration =1541
# V_current = 1.8861706150734125e-09
# number of iteration =1542
# V_current = 1.8856915320367676e-09
# number of iteration =1543
# V_current = 1.8860709272481447e-09
# number of iteration =1544
# V_current = 1.886450323477291e-09
# number of iteration =1545
# V_current = 1.8864004972385173e-09
# number of iteration =1546
# V_current = 1.8842045810962276e-09
# number of iteration =1547
# V_current = 1.885013222751168e-09
# number of iteration =1548
# V_current = 1.887538706336685e-09
# number of iteration =1549
# V_current = 1.8874889030191874e-09
# number of iteration =1550
# V_current = 1.8861514946013584e-09
# number of iteration =1551
# V_current = 1.8861017197582914e-09
# number of iteration =1552
# V_current = 1.8860519534677172e-09
# number of iteration =1553
# V_current = 1.8847146161549875e-09
# number of iteration =1554
# V_current = 1.8863816359303426e-09
# number of iteration =1555
# V_current = 1.8867610770975755e-09
# number of iteration =1556
# V_current = 1.8862821555764767e-09
# number of iteration =1557
# V_current = 1.8858032501680856e-09
# number of iteration =1558
# V_current = 1.884895186628282e-09
# number of iteration =1559
# V_current = 1.8865621694830122e-09
# number of iteration =1560
# V_current = 1.8865124638910768e-09
# number of iteration =1561
# V_current = 1.8864627668162243e-09
# number of iteration =1562
# V_current = 1.884267282885987e-09
# number of iteration =1563
# V_current = 1.885075932361403e-09
# number of iteration =1564
# V_current = 1.883309666250524e-09
# number of iteration =1565
# V_current = 1.8854057682274744e-09
# number of iteration =1566
# V_current = 1.8857852651682194e-09
# number of iteration =1567
# V_current = 1.8844482026062657e-09
# number of iteration =1568
# V_current = 1.88439858022869e-09
# number of iteration =1569
# V_current = 1.8856363638682825e-09
# number of iteration =1570
# V_current = 1.8855867470738243e-09
# number of iteration =1571
# V_current = 1.8863953885891156e-09
# number of iteration =1572
# V_current = 1.8842001755698007e-09
# number of iteration =1573
# V_current = 1.8854379475544358e-09
# number of iteration =1574
# V_current = 1.8832427970598095e-09
# number of iteration =1575
# V_current = 1.8866261193835244e-09
# number of iteration =1576
# V_current = 1.8861474360918552e-09
# number of iteration =1577
# V_current = 1.8856687688571473e-09
# number of iteration =1578
# V_current = 1.884331921040954e-09
# number of iteration =1579
# V_current = 1.8847114825498928e-09
# number of iteration =1580
# V_current = 1.885949226330704e-09
# number of iteration =1581
# V_current = 1.883754260444222e-09
# number of iteration =1582
# V_current = 1.8849920058963175e-09
# number of iteration =1583
# V_current = 1.8858006576581333e-09
# number of iteration =1584
# V_current = 1.8861802271338123e-09
# number of iteration =1585
# V_current = 1.8831272238565066e-09
# number of iteration =1586
# V_current = 1.881790553838289e-09
# number of iteration =1587
# V_current = 1.885173620016618e-09
# number of iteration =1588
# V_current = 1.8829788500852543e-09
# number of iteration =1589
# V_current = 1.882929408996205e-09
# number of iteration =1590
# V_current = 1.8837380816493614e-09
# number of iteration =1591
# V_current = 1.884117698621544e-09
# number of iteration =1592
# V_current = 1.8827811361816256e-09
# number of iteration =1593
# V_current = 1.8840188524383054e-09
# number of iteration =1594
# V_current = 1.8848275168046597e-09
# number of iteration =1595
# V_current = 1.8813458381023244e-09
# number of iteration =1596
# V_current = 1.882583556681029e-09
# number of iteration =1597
# V_current = 1.8851083387865934e-09
# number of iteration =1598
# V_current = 1.886346016969652e-09
# number of iteration =1599
# V_current = 1.8824354601165464e-09
# number of iteration =1600
# Iteration elapsed: 1600
# Time elapsed:1800.54 s
# Amount of highest displacement: 0.05 mikrometer
# V_current = 1.8845311841805363e-09
# number of iteration =1601
# V_current = 1.88533984622798e-09
# number of iteration =1602
# V_current = 1.8831454528043795e-09
# number of iteration =1603
# V_current = 1.883096121511588e-09
# number of iteration =1604
# V_current = 1.883475797890529e-09
# number of iteration =1605
# V_current = 1.8829974839995925e-09
# number of iteration =1606
# V_current = 1.8825191860902454e-09
# number of iteration =1607
# V_current = 1.8816119162930918e-09
# number of iteration =1608
# V_current = 1.8832785744124235e-09
# number of iteration =1609
# V_current = 1.8815133684649844e-09
# number of iteration =1610
# V_current = 1.882751036313364e-09
# number of iteration =1611
# V_current = 1.8839886895914803e-09
# number of iteration =1612
# V_current = 1.884368390727758e-09
# number of iteration =1613
# V_current = 1.8821743027727417e-09
# number of iteration =1614
# V_current = 1.882982989338455e-09
# number of iteration =1615
# V_current = 1.8837916689459187e-09
# number of iteration =1616
# V_current = 1.8820266205611066e-09
# number of iteration =1617
# V_current = 1.8832642588397257e-09
# number of iteration =1618
# V_current = 1.88321504491231e-09
# number of iteration =1619
# V_current = 1.884023723372222e-09
# number of iteration =1620
# V_current = 1.881400889087935e-09
# number of iteration =1621
# V_current = 1.8834963873379287e-09
# number of iteration =1622
# V_current = 1.8825893416343974e-09
# number of iteration =1623
# V_current = 1.880395539261587e-09
# number of iteration =1624
# V_current = 1.882062089756754e-09
# number of iteration =1625
# V_current = 1.8837286179425807e-09
# number of iteration =1626
# V_current = 1.8811059710332027e-09
# number of iteration =1627
# V_current = 1.881914669921236e-09
# number of iteration =1628
# V_current = 1.881436638900638e-09
# number of iteration =1629
# V_current = 1.883532046603402e-09
# number of iteration =1630
# V_current = 1.879622824677302e-09
# number of iteration =1631
# V_current = 1.8812893298024274e-09
# number of iteration =1632
# V_current = 1.882955812567125e-09
# number of iteration =1633
# V_current = 1.8816200535307774e-09
# number of iteration =1634
# V_current = 1.8807132103786827e-09
# number of iteration =1635
# V_current = 1.881093033288819e-09
# number of iteration =1636
# V_current = 1.8823306107910726e-09
# number of iteration =1637
# V_current = 1.882281554036867e-09
# number of iteration =1638
# V_current = 1.8835191135457665e-09
# number of iteration =1639
# V_current = 1.8826123307471577e-09
# number of iteration =1640
# V_current = 1.8799901247856674e-09
# number of iteration =1641
# V_current = 1.8816565515085264e-09
# number of iteration =1642
# V_current = 1.8811786857223666e-09
# number of iteration =1643
# V_current = 1.882845086732217e-09
# number of iteration =1644
# V_current = 1.879794155457436e-09
# number of iteration =1645
# V_current = 1.8810317112158025e-09
# number of iteration =1646
# V_current = 1.880125058777898e-09
# number of iteration =1647
# V_current = 1.881791438959144e-09
# number of iteration =1648
# V_current = 1.879598317570134e-09
# number of iteration =1649
# V_current = 1.8812646873078578e-09
# number of iteration =1650
# V_current = 1.8820733878770235e-09
# number of iteration =1651
# V_current = 1.8811668032855885e-09
# number of iteration =1652
# V_current = 1.880689057895219e-09
# number of iteration =1653
# V_current = 1.8806401401923985e-09
# number of iteration =1654
# V_current = 1.881448846649574e-09
# number of iteration =1655
# V_current = 1.879255916880512e-09
# number of iteration =1656
# V_current = 1.879635835543253e-09
# number of iteration =1657
# V_current = 1.881730940587411e-09
# number of iteration =1658
# V_current = 1.8795380890844925e-09
# number of iteration =1659
# V_current = 1.879060439314968e-09
# number of iteration =1660
# V_current = 1.880726730142559e-09
# number of iteration =1661
# V_current = 1.881106655072016e-09
# number of iteration =1662
# V_current = 1.8814865804726203e-09
# number of iteration =1663
# V_current = 1.8810089594892555e-09
# number of iteration =1664
# V_current = 1.8796738151732936e-09
# number of iteration =1665
# V_current = 1.8804825307568934e-09
# number of iteration =1666
# V_current = 1.879576191525216e-09
# number of iteration =1667
# V_current = 1.8808136660657196e-09
# number of iteration =1668
# V_current = 1.8794786004315717e-09
# number of iteration =1669
# V_current = 1.8794298170841875e-09
# number of iteration =1670
# V_current = 1.8793810418652628e-09
# number of iteration =1671
# V_current = 1.880189760113038e-09
# number of iteration =1672
# V_current = 1.8788547769747323e-09
# number of iteration =1673
# V_current = 1.8796634999230254e-09
# number of iteration =1674
# V_current = 1.8800434844672897e-09
# number of iteration =1675
# V_current = 1.8821383785581896e-09
# number of iteration =1676
# V_current = 1.8790885610599502e-09
# number of iteration =1677
# V_current = 1.879897281817615e-09
# number of iteration =1678
# V_current = 1.880705995280545e-09
# number of iteration =1679
# V_current = 1.879371142005656e-09
# number of iteration =1680
# V_current = 1.8810372761856583e-09
# number of iteration =1681
# V_current = 1.8814172750922694e-09
# number of iteration =1682
# V_current = 1.8792250723658913e-09
# number of iteration =1683
# V_current = 1.8783190056892774e-09
# number of iteration =1684
# V_current = 1.880842503565752e-09
# number of iteration =1685
# V_current = 1.8807938306087578e-09
# number of iteration =1686
# V_current = 1.878601741082785e-09
# number of iteration =1687
# V_current = 1.8798391467585936e-09
# number of iteration =1688
# V_current = 1.878933151272943e-09
# number of iteration =1689
# V_current = 1.8797418727374548e-09
# number of iteration =1690
# V_current = 1.8788359087922086e-09
# number of iteration =1691
# V_current = 1.878787299640085e-09
# number of iteration =1692
# V_current = 1.8808820075578265e-09
# number of iteration =1693
# V_current = 1.877832789601091e-09
# number of iteration =1694
# V_current = 1.877355558223544e-09
# number of iteration =1695
# V_current = 1.879021593777159e-09
# number of iteration =1696
# V_current = 1.880258960139266e-09
# number of iteration =1697
# V_current = 1.878495813754411e-09
# number of iteration =1698
# V_current = 1.8788758995758184e-09
# number of iteration =1699
# V_current = 1.8788273509082325e-09
# number of iteration =1700
# Iteration elapsed: 1700
# Time elapsed:1912.80 s
# Amount of highest displacement: 0.05 mikrometer
# V_current = 1.8770642864894517e-09
# number of iteration =1701
# V_current = 1.8795875318234755e-09
# number of iteration =1702
# V_current = 1.8791103762837755e-09
# number of iteration =1703
# V_current = 1.8794904752124273e-09
# number of iteration =1704
# V_current = 1.8772988814041818e-09
# number of iteration =1705
# V_current = 1.879822062299916e-09
# number of iteration =1706
# V_current = 1.877630519260184e-09
# number of iteration =1707
# V_current = 1.8775820424457556e-09
# number of iteration =1708
# V_current = 1.876676373517184e-09
# number of iteration =1709
# V_current = 1.877913709016183e-09
# number of iteration =1710
# V_current = 1.8795796216649493e-09
# number of iteration =1711
# V_current = 1.877388215179061e-09
# number of iteration =1712
# V_current = 1.8773397783439e-09
# number of iteration =1713
# V_current = 1.8790056724551528e-09
# number of iteration =1714
# V_current = 1.8772429286287116e-09
# number of iteration =1715
# V_current = 1.8771945157422103e-09
# number of iteration =1716
# V_current = 1.8788603874080425e-09
# number of iteration =1717
# V_current = 1.8796691055617508e-09
# number of iteration =1718
# V_current = 1.8779064477505004e-09
# number of iteration =1719
# V_current = 1.877429501472126e-09
# number of iteration =1720
# V_current = 1.8773811245679527e-09
# number of iteration =1721
# V_current = 1.8769042058151067e-09
# number of iteration =1722
# V_current = 1.8768558486958604e-09
# number of iteration =1723
# V_current = 1.877236041601899e-09
# number of iteration =1724
# V_current = 1.8771876965180034e-09
# number of iteration =1725
# V_current = 1.8758537563836194e-09
# number of iteration =1726
# V_current = 1.8775195606506417e-09
# number of iteration =1727
# V_current = 1.877899762119771e-09
# number of iteration =1728
# V_current = 1.874851782015961e-09
# number of iteration =1729
# V_current = 1.8769460902404845e-09
# number of iteration =1730
# V_current = 1.8764692778131362e-09
# number of iteration =1731
# V_current = 1.877278014375176e-09
# number of iteration =1732
# V_current = 1.8763727144395876e-09
# number of iteration =1733
# V_current = 1.876752947997404e-09
# number of iteration =1734
# V_current = 1.877133181727094e-09
# number of iteration =1735
# V_current = 1.8757994331735146e-09
# number of iteration =1736
# V_current = 1.876608174469252e-09
# number of iteration =1737
# V_current = 1.876559932448525e-09
# number of iteration =1738
# V_current = 1.8795110862529524e-09
# number of iteration =1739
# V_current = 1.8756065118952075e-09
# number of iteration =1740
# V_current = 1.8772722062818903e-09
# number of iteration =1741
# V_current = 1.876795515751762e-09
# number of iteration =1742
# V_current = 1.877175777834964e-09
# number of iteration =1743
# V_current = 1.874985252414427e-09
# number of iteration =1744
# V_current = 1.877079380944549e-09
# number of iteration =1745
# V_current = 1.877459651175924e-09
# number of iteration =1746
# V_current = 1.875269203696544e-09
# number of iteration =1747
# V_current = 1.8765063956291e-09
# number of iteration =1748
# V_current = 1.877315126946822e-09
# number of iteration =1749
# V_current = 1.875553202610655e-09
# number of iteration =1750
# V_current = 1.875933504453133e-09
# number of iteration =1751
# V_current = 1.876742239973351e-09
# number of iteration =1752
# V_current = 1.877550967831449e-09
# number of iteration =1753
# V_current = 1.876217558965856e-09
# number of iteration =1754
# V_current = 1.8761694470331624e-09
# number of iteration =1755
# V_current = 1.876978179046872e-09
# number of iteration =1756
# V_current = 1.874788004227138e-09

# %%
HC = dummy_parameter2['HC']
iteration_list = dummy_parameter2['iteration_list']
df_list_max = dummy_parameter2['df_list_max']
volume_list = dummy_parameter2['volume_list']
contact_angle_list_bottom = dummy_parameter2['contact_angle_list_bottom']

# %%
from ddgclib._plotting import *
plot_polyscope(HC)

if 0:
    load_filename = 'dl'+str(r_l*2)+'_du'+str(r_u*2)+'_l'+str(length)+'_ref'+str(refinement)+'_contactangle'+str(theta_p)+'_tau'+str(tau)+'_itermax'+str(1000)+'.json'
    load_filename = 'dl0.002604722665003955_du0.002604722665003955_l0.003_ref3_contactangle1.064650843716541_tau1_itermax1000.json'
    HC_load = Complex(3)
    HC_load.load_complex(load_filename)
    plot_polyscope(HC_load)


#plot_polyscope(dummy_parameter2['HC'])

# %%
#gamma

# %%
vlist = []


for v in HC.V:
    if (abs(v.x[0]) <= 1e-8) and (0.5e-3 <= v.x[1] <= 16):
        vlist.append(v.x)


sorted_list = sorted(vlist, key=lambda x: x[-1])

vlist_x = []
vlist_y = []
vlist_z = []

for v in sorted_list:
    vlist_x.append(v[0])
    vlist_y.append(v[1])
    vlist_z.append(v[2])

coordiante_dict = {'vlist_x':vlist_x, 'vlist_y':vlist_y, 'vlist_z':vlist_z}

# %%
#coordiante_dict_500 = coordiante_dict
#coordiante_dict_1000 = coordiante_dict
diameter = r_l * 1e3 * 2

rounded_diameter = round(diameter, 1)
rounded_length = round(length*1e3, 1)

iteration_max = 100*1e3

string_savename     = 'd'+ str(rounded_diameter) + 'mm_' + 'l' + str(rounded_length) + 'mm_'  + 'iteration' +str(iteration_max)
string_loadname_x   = 'd'+ str(rounded_diameter) + 'mm_' + 'l' + str(rounded_length) + 'mm_'  + 'iteration' +str(15000)


np.savetxt(string_savename + '_y'+ 'refinement4'+ '.txt',coordiante_dict['vlist_y'])
np.savetxt(string_savename + '_z'+ 'refinement4'+ '.txt',coordiante_dict['vlist_z'])
np.savetxt(string_savename + 'dfmax'+ 'refinement4'+ '.txt',dummy_parameter2['df_list_max'])

# %%
load_iteration = 5000
string_loadname_x   = 'd'+ str(rounded_diameter) + 'mm_' + 'l' + str(rounded_length) + 'mm_'  + 'iteration' +str(load_iteration) +'dfmax'+ '.txt'
df_list_5000              = np.loadtxt(string_loadname_x)

load_iteration = 15000
string_loadname_x   = 'd'+ str(rounded_diameter) + 'mm_' + 'l' + str(rounded_length) + 'mm_'  + 'iteration' +str(load_iteration) +'dfmax'+ '.txt'
df_list_15000              = np.loadtxt(string_loadname_x)

load_iteration = 25000
string_loadname_x   = 'd'+ str(rounded_diameter) + 'mm_' + 'l' + str(rounded_length) + 'mm_'  + 'iteration' +str(load_iteration) +'dfmax'+ '.txt'
df_list_25000              = np.loadtxt(string_loadname_x)

load_iteration = 35000
string_loadname_x   = 'd'+ str(rounded_diameter) + 'mm_' + 'l' + str(rounded_length) + 'mm_'  + 'iteration' +str(load_iteration) +'dfmax'+ '.txt'
df_list_35000              = np.loadtxt(string_loadname_x)

combined_array = np.concatenate((df_list_5000, df_list_15000,df_list_25000, df_list_35000))

iteration_array = np.arange(len(combined_array))

# %%
iteration_max_load = 0
string_savename     = 'd'+ str(rounded_diameter) + 'mm_' + 'l' + str(rounded_length) + 'mm_'  + 'iteration' +str(iteration_max_load)

y_coordinates_0              = np.loadtxt(string_savename + '_y'+ '.txt')
z_coordinates_0              = np.loadtxt(string_savename + '_z'+ '.txt')


iteration_max_load = 100
string_savename     = 'd'+ str(rounded_diameter) + 'mm_' + 'l' + str(rounded_length) + 'mm_'  + 'iteration' +str(iteration_max_load)

y_coordinates_100              = np.loadtxt(string_savename + '_y'+ '.txt')
z_coordinates_100              = np.loadtxt(string_savename + '_z'+ '.txt')

iteration_max_load = 500
string_savename     = 'd'+ str(rounded_diameter) + 'mm_' + 'l' + str(rounded_length) + 'mm_'  + 'iteration' +str(iteration_max_load)

y_coordinates_500              = np.loadtxt(string_savename + '_y'+ '.txt')
z_coordinates_500              = np.loadtxt(string_savename + '_z'+ '.txt')

iteration_max_load = 1000
string_savename     = 'd'+ str(rounded_diameter) + 'mm_' + 'l' + str(rounded_length) + 'mm_'  + 'iteration' +str(iteration_max_load)

y_coordinates_1000              = np.loadtxt(string_savename + '_y'+ '.txt')
z_coordinates_1000              = np.loadtxt(string_savename + '_z'+ '.txt')

iteration_max_load = 5000
string_savename     = 'd'+ str(rounded_diameter) + 'mm_' + 'l' + str(rounded_length) + 'mm_'  + 'iteration' +str(iteration_max_load)

y_coordinates_5000              = np.loadtxt(string_savename + '_y'+ '.txt')
z_coordinates_5000              = np.loadtxt(string_savename + '_z'+ '.txt')

iteration_max_load = 15000
string_savename     = 'd'+ str(rounded_diameter) + 'mm_' + 'l' + str(rounded_length) + 'mm_'  + 'iteration' +str(iteration_max_load)

y_coordinates_15000              = np.loadtxt(string_savename + '_y'+ '.txt')
z_coordinates_15000              = np.loadtxt(string_savename + '_z'+ '.txt')

iteration_max_load = 25000
string_savename     = 'd'+ str(rounded_diameter) + 'mm_' + 'l' + str(rounded_length) + 'mm_'  + 'iteration' +str(iteration_max_load)

y_coordinates_25000              = np.loadtxt(string_savename + '_y'+ '.txt')
z_coordinates_25000              = np.loadtxt(string_savename + '_z'+ '.txt')

iteration_max_load = 35000
string_savename     = 'd'+ str(rounded_diameter) + 'mm_' + 'l' + str(rounded_length) + 'mm_'  + 'iteration' +str(iteration_max_load)

y_coordinates_35000              = np.loadtxt(string_savename + '_y'+ '.txt')
z_coordinates_35000              = np.loadtxt(string_savename + '_z'+ '.txt')

iteration_max_load = 100000
string_savename     = 'd'+ str(rounded_diameter) + 'mm_' + 'l' + str(rounded_length) + 'mm_'  + 'iteration' +str(iteration_max_load) + 'refinement4'

y_coordinates_35000              = np.loadtxt(string_savename + '_y'+ '.txt')
z_coordinates_35000              = np.loadtxt(string_savename + '_z'+ '.txt')

# %% [markdown]
# # Plotting of the results

# %%
'''
Plot of the residual data
'''


plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.sans-serif"] = "Arial"
plt.rcParams["mathtext.fontset"] = "custom"
plt.rcParams["mathtext.it"] = "Arial:italic"
plt.rcParams["mathtext.rm"] = "Arial"
plt.rcParams["mathtext.default"] = "it"
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['axes.titlesize'] = 12
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['legend.fontsize'] = 12

#fig_name = "contact_angle_notactivated10_20240219.png"
fig_name = "example_calculation_lian_100000iteration_refinement4.png"
#fig, ax = plot.subplots(nrows=1, ncols=2, figsize=(6, 5))
fig, ax = plot.subplots(nrows=1, ncols=2, figsize=(12, 5))

#ax[0].plot(vlist_z, vlist_y, linestyle = '--', markersize = 5, marker = 'o', linewidth = 1)
#ax[0].plot(coordiante_dict['vlist_z'], coordiante_dict['vlist_y'], linestyle = '--', markersize = 5, marker = 'o', linewidth = 1)
if 0:
    ax[0].plot(z_coordinates_0, y_coordinates_0, linestyle = '--', markersize = 5, marker = 'o', linewidth = 1, label = '0')
    ax[0].plot(z_coordinates_100, y_coordinates_100, linestyle = '--', markersize = 5, marker = 'o', linewidth = 1, label = '100')
    ax[0].plot(z_coordinates_500, y_coordinates_500, linestyle = '--', markersize = 5, marker = 'o', linewidth = 1, label = '500')
    ax[0].plot(z_coordinates_1000, y_coordinates_1000, linestyle = '--', markersize = 5, marker = 'o', linewidth = 1, label = '1000')
    ax[0].plot(z_coordinates_5000, y_coordinates_5000, linestyle = '--', markersize = 5, marker = 'o', linewidth = 1, label = '5000')
    ax[0].plot(z_coordinates_15000, y_coordinates_15000, linestyle = '--', markersize = 5, marker = 'o', linewidth = 1, label = '15000')
    ax[0].plot(z_coordinates_25000, y_coordinates_15000, linestyle = '--', markersize = 5, marker = 'o', linewidth = 1, label = '25000')

if 1:
    ax[0].plot(z_coordinates_0*1e3, y_coordinates_0*1e3, linestyle = '--', markersize = 5, marker = 'o', linewidth = 1, label = '0')
    ax[0].plot(z_coordinates_100*1e3, y_coordinates_100*1e3, linestyle = '--', markersize = 5, marker = 'o', linewidth = 1, label = '100')
    ax[0].plot(z_coordinates_500*1e3, y_coordinates_500*1e3, linestyle = '--', markersize = 5, marker = 'o', linewidth = 1, label = '500')
    ax[0].plot(z_coordinates_1000*1e3, y_coordinates_1000*1e3, linestyle = '--', markersize = 5, marker = 'o', linewidth = 1, label = '1000')
    ax[0].plot(z_coordinates_5000*1e3, y_coordinates_5000*1e3, linestyle = '--', markersize = 5, marker = 'o', linewidth = 1, label = '5000')
    ax[0].plot(z_coordinates_15000*1e3, y_coordinates_15000*1e3, linestyle = '--', markersize = 5, marker = 'o', linewidth = 1, label = '15000')
    ax[0].plot(z_coordinates_25000*1e3, y_coordinates_25000*1e3, linestyle = '--', markersize = 5, marker = 'o', linewidth = 1, label = '25000')
    ax[0].plot(z_coordinates_35000*1e3, y_coordinates_35000*1e3, linestyle = '--', markersize = 5, marker = 'o', linewidth = 1, label = '35000')
    ax[0].plot(z_coordinates_100000*1e3, y_coordinates_100000*1e3, linestyle = '--', markersize = 5, marker = 'o', linewidth = 1, label = '100000')
# ax[0].plot(coordiante_dict_500['vlist_z'], coordiante_dict_1000['vlist_y'], linestyle = '--', markersize = 5, marker = 'o', linewidth = 1)
#ax[0].hlines(50,-10,2300, colors = 'red', linestyle = '--')
#*1e3
#ax[0].set_yscale('log')

#ax[1].plot(iteration_list, contact_angle_list_top)
ax[1].plot(iteration_list, df_list_max)
if 0:
    ax[1].plot(iteration_array, combined_array)
#ax[1].plot(iteration_list, dHNdA_list_min)

#hlines(y, xmin, xmax, colors=None, linestyles='solid'

ax[0].set_title('(a)')
ax[1].set_title('(b)')

ax[0].set_xlabel("z-Pos. / mm")
ax[0].set_ylabel("y-Pos. / mm")

ax[1].set_xlabel("i")
ax[1].set_ylabel("df / m ")

#ax[0].set_ylim(45, 91)
#ax[0].set_xlim(0, itermax)


ax[1].set_yscale('log')
#ax[1].set_ylim(0, 91)
ax[1].set_xlim(0, iteration_array[-1])
ax[0].legend()

plt.tight_layout()



fig.savefig(fig_name)

# %%
'''
Some not ready defined functions
'''
def b_force(v, theta_p, print_out=True):
    """
    The force on the three-phase contact angle
    Theta_i: Estimated sector angle of vertex i
    theta_p: Equilibrium three-phase contact angle
    """


    phi_est, l_a = b_disc_angle(v)
    # Compute boundary forces
    # N m-1
    gamma_bt = gamma * (np.cos(phi_est)
                        - np.cos(theta_p)) * np.array([0, 0, 1.0])

    if print_out:
        print(f'phi_est  = {phi_est * 180 / np.pi}')
        #print(f'dK[i] = {dK[i]}')
    return gamma_bt


def b_move_vertex(v, Theta_i, theta_p, print_out=True):
    """
    Move the boundary vertex
    """

    F_bt = gamma_bt * l_a  # N
    new_vx = v.x + 1e-1 * F_bt
    new_vx = tuple(new_vx)
    HC.V.move(v, new_vx)
    bV_new.add(HC.V[new_vx])

# %%
'''
Plotting of the normvecs (dir_vecs)
'''

plot_polyscope_plus_normvec(HC, N_f0_vectors_pairs)

# %% [markdown]
# # Using the Function
