# %%
# Imports and physical parameters
import numpy as np
import scipy

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.patches import FancyArrowPatch
from mpl_toolkits.mplot3d import proj3d
from ipywidgets import *
from matplotlib.widgets import Slider

# ddg imports
import os, sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from ddgclib._particle_liquid_bridge_flo import *


# Parameters for
# a water droplet in air at standard laboratory conditions

#rho = 1000  # kg/m3, density
#g = 9.81  # m/s2

# Numerical parameters #Stated this is what to plaay
#r = 1
#theta_p = 20 * np.pi/180.0  # rad, three phase contact angle

refinement=3# NOTE: 2 is the minimum refinement needed for the complex to be manifold
gamma = 0.0728  # N/m, surface tension of water at 20 deg C


diameter    = 1     # diameter in m
t_f         = 100     # End-Residual-Time // if t_f = 0, no optimization
tau         = 0.2   # step-size
length      = 1     # length of the initial cylinder

# v_l         = -0.5  # lower length-coordinate
# v_u         = 0.5   # higher length-coordinate

v_l         = 0 - length/2  # lower length-coordinate
v_u         = 0 + length/2   # higher length-coordinate

# %%
dummy_parameter = fun_liquid_bridge(v_l, v_u,tau, t_f,diameter, refinement,gamma) # v_l, v_u, tau, tf, d
HC = dummy_parameter[0]
iteration_list = dummy_parameter[1]
df_list_min = dummy_parameter[2]
df_list_max = dummy_parameter[3]

# %%
'''
Plot of the residual data
'''
fig, ax = plot.subplots(nrows=1, ncols=2, figsize=(12, 6))


ax[0].plot(iteration_list, df_list_max)
ax[0].plot(iteration_list, df_list_min)

#ax[1].plot(iteration_list, dHNdA_list_max)
#ax[1].plot(iteration_list, dHNdA_list_min)



ax[0].set_title('Residuals for df')
ax[1].set_title('Residuals for HNdA')
# Out:
# Text(0.5, 1.0, 'Residuals for HNdA')

# %%
#plot_polyscope(HC)
print(df_list_max)
# Out:
# [0.04451636483392806, 0.04294356139218729, 0.04121397528685752, 0.0393356807896532, 0.03732691126606997, 0.035216131469213444, 0.03304025512578839, 0.03084116529236339, 0.028661313915273032, 0.026539488849013373, 0.02450767725874134, 0.022589464503534724, 0.020799886695506087, 0.019146328602695772, 0.017629974977501756, 0.01624740604788279, 0.014992072717719363, 0.013855521999911507, 0.012828338675215847, 0.01190082367493169, 0.011063453573477293, 0.010307170729881653, 0.009623549248964114, 0.009004873897040962, 0.008444160588603127, 0.007935139513156901, 0.00747221587115791, 0.0070504185274631375, 0.006665343465067586, 0.006313096475800007, 0.005990237819214052, 0.005693730417613166, 0.005449080911331162, 0.005370989924183314, 0.005298631077764722, 0.005230917499598466, 0.005166971490145737, 0.005106087296192035, 0.005047700132200483, 0.004991360456398284, 0.004936712653960222, 0.004883477407597649, 0.004850076972473861, 0.004838686314764031, 0.004825088355814603, 0.0048095950772169055, 0.0047924759460640535, 0.004773964211714087, 0.0047542622117021606, 0.004733545847444671, 0.004711968364061328, 0.004689663546655409, 0.0046667484269742295, 0.004643325578983946, 0.0046194850690376476, 0.004595306115575357, 0.004570858504317131, 0.004546203797426256, 0.004521396368857739, 0.0044964842928893875, 0.004471510108462004, 0.004446511478307938, 0.004421521758816658, 0.0043965704940173616, 0.004379323404022515, 0.004376896418017491, 0.004374099073475313, 0.004370947785205004, 0.004367457995437507, 0.004363644281285829, 0.004359520445132211, 0.00435509959088279, 0.004350394188518152, 0.
# self.V[v].index = 21
# self.V[v].index = 22
# self.V[v].index = 23
# self.V[v].index = 24
# self.V[v].index = 25
# self.V[v].index = 27
# self.V[v].index = 28
# self.V[v].index = 29
# self.V[v].index = 30
# self.V[v].index = 32
# self.V[v].index = 33
# self.V[v].index = 34
# self.V[v].index = 35
# self.V[v].index = 36
# self.V[v].index = 37
# self.V[v].index = 38
# self.V[v].index = 39
# self.V[v].index = 40
# self.V[v].index = 41
# self.V[v].index = 42
# self.V[v].index = 43
# self.V[v].index = 44
# self.V[v].index = 45
# self.V[v].index = 46
# self.V[v].index = 47
# self.V[v].index = 48
# self.V[v].index = 49
# self.V[v].index = 50
# self.V[v].index = 51
# self.V[v].index = 52
# self.V[v].index = 54
# self.V[v].index = 55
# self.V[v].index = 56
# self.V[v].index = 57
# self.V[v].index = 58
# self.V[v].index = 60
# self.V[v].index = 61
# self.V[v].index = 62
# self.V[v].index = 63
# self.V[v].index = 64
# self.V[v].index = 65
# self.V[v].index = 66
# self.V[v].index = 67
# self.V[v].index = 68
# self.V[v].index = 69
# self.V[v].index = 70
# self.V[v].index = 71
# self.V[v].index = 72
# self.V[v].index = 73
# self.V[v].index = 74
# self.V[v].index = 75
# self.V[v].index = 76
# self.V[v].index = 77
# self.V[v].index = 78
# self.V[v].index = 80
# self.V[v].index = 81
# self.V[v].index = 82
# self.V[v].index = 83
# self.V[v].index = 84
# self.V[v].index = 85
# self.V[v].index = 87
# self.V[v].index = 88
# self.V[v].index = 89
# self.V[v].index = 90
# self.V[v].index = 91
# self.V[v].index = 92
# self.V[v].index = 93
# self.V[v].index = 94
# self.V[v].index = 95
# self.V[v].index = 96
# self.V[v].index = 97
# self.V[v].index = 98
# self.V[v].index = 99
# self.V[v].index = 100
# self.V[v].index = 101
# self.V[v].index = 102
# self.V[v].index = 103
# self.V[v].index = 105
# self.V[v].index = 106
# self.V[v].index = 107
# self.V[v].index = 108
# self.V[v].index = 110
# self.V[v].index = 111
# self.V[v].index = 112
# self.V[v].index = 113
# self.V[v].index = 114
# self.V[v].index = 115
# self.V[v].index = 116
# self.V[v].index = 117
# self.V[v].index = 118
# self.V[v].index = 119
# self.V[v].index = 120
# self.V[v].index = 121
# self.V[v].index = 122
# self.V[v].index = 123
# self.V[v].index = 124
# self.V[v].index = 126
# self.V[v].index = 127
# self.V[v].index = 128
# self.V[v].index = 129
# self.V[v].index = 130
# self.V[v].index = 132
# self.V[v].index = 133
# self.V[v].index = 134
# self.V[v].index = 135

# %% [markdown]
# # Volume calculating Flo

# %%
V = 0
for v in HC.V:
    V_ijk = volume(v)
    #print(V_ijk)
    V += np.sum(V_ijk)

V = V/12

# %%
V
# Out:
# 0.7459468368823017

# %%
def fun_V_analytic(r, v_l, v_u):
    V_an = np.pi/4*r**2*(v_u-v_l)
    return V_an

# %%
fun_V_analytic(1,-0.5,0.5)
# Out:
# 0.7853981633974483

# %% [markdown]
# # Save and load from complexes

# %%
'''
Save and load don't work --> ask Stefan
'''
#HC.save_complex(fn='data.json')
# Out:
# "\nSave and load don't work --> ask Stefan\n"
