# %%
import numpy as np
from matplotlib import pyplot as plt
kappa = 1
def y(x, theta):
    return (-x * np.sin(theta) + np.sqrt((1/kappa)**2 - x**2) * np.cos(theta))




xspan = np.linspace(0, 1)
theta = 0.9* np.pi

theta = 0

theta = np.pi/4


plt.plot(xspan, y(xspan, theta))

# %%
import numpy as np
from matplotlib import pyplot as plt


#y(x) = r*sqrt(1 - (x/r)²)

# It's only valid for |x| ≤ 1/κ
kappa = 1
r = 1/kappa
xspan = np.linspace(-1/kappa, 1/kappa)
def y(x):  # integrated change in y for change in x, starting
    return  -r*np.sqrt(1 - (x/r)**2)

plt.plot(xspan, y(xspan))
plt.ylim((-1,1))
# Out:
# (-1.0, 1.0)

# %%
def theta(x):
    np.arctan(-x/np.sqrt(r**2 - x**2))

# %%
print(theta(xspan[1]))
# Out:
# None

# %%
xspan
# Out:
# array([-1.        , -0.95918367, -0.91836735, -0.87755102, -0.83673469,
#        -0.79591837, -0.75510204, -0.71428571, -0.67346939, -0.63265306,
#        -0.59183673, -0.55102041, -0.51020408, -0.46938776, -0.42857143,
#        -0.3877551 , -0.34693878, -0.30612245, -0.26530612, -0.2244898 ,
#        -0.18367347, -0.14285714, -0.10204082, -0.06122449, -0.02040816,
#         0.02040816,  0.06122449,  0.10204082,  0.14285714,  0.18367347,
#         0.2244898 ,  0.26530612,  0.30612245,  0.34693878,  0.3877551 ,
#         0.42857143,  0.46938776,  0.51020408,  0.55102041,  0.59183673,
#         0.63265306,  0.67346939,  0.71428571,  0.75510204,  0.79591837,
#         0.83673469,  0.87755102,  0.91836735,  0.95918367,  1.        ])

# %%
xspan[0]
# Out:
# array([-0.        , -0.28278381, -0.39572897, -0.47948327, -0.54760848,
#        -0.60540396, -0.65560728, -0.69985421, -0.73921511, -0.77443535,
#        -0.80605786, -0.83449177, -0.86005337, -0.88299215, -0.9035079 ,
#        -0.92176243, -0.93788778, -0.95199215, -0.96416423, -0.97447644,
#        -0.98298731, -0.98974332, -0.99478021, -0.99812402, -0.99979173,
#        -0.99979173, -0.99812402, -0.99478021, -0.98974332, -0.98298731,
#        -0.97447644, -0.96416423, -0.95199215, -0.93788778, -0.92176243,
#        -0.9035079 , -0.88299215, -0.86005337, -0.83449177, -0.80605786,
#        -0.77443535, -0.73921511, -0.69985421, -0.65560728, -0.60540396,
#        -0.54760848, -0.47948327, -0.39572897, -0.28278381, -0.        ])

# %%
# Out:
# -0.0
