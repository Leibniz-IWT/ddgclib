# %%
from src._analytical_equil import set_equilibrium_IC_2d, test_analytical_equilibrium_2d
from src._complex import Complex   # or your 2D mesh function

print("\n=== 2D Planar Channel Test (optional) ===")
domain_2d = [(0, L), (0, r*2)]  # x along flow, y from 0 to D
HC2d = ...  # use your incomp_poiseuille_2d or similar

set_equilibrium_IC_2d(HC2d, G=G, mu=mu, h=r*2)
compute_vd(HC2d, cdist=cdist)
test_analytical_equilibrium_2d(HC2d, G=G, mu=mu, h=r*2)
