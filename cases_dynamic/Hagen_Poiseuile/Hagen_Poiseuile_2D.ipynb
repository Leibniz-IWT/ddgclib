# %%
from src._analytical_equil import set_equilibrium_IC_2d, test_analytical_equilibrium_2d
from src._params import L, r, G, mu, cdist
from hyperct import Complex
from hyperct.ddg import compute_vd

print("\n=== 2D Planar Channel Test (optional) ===")
domain_2d = [(0, L), (0, r*2)]  # x along flow, y from 0 to D

# Geometry
HC = Complex(2) # use your incomp_poiseuille_2d or similar
HC.triangulate()
HC.refine_all()
HC.refine_all()

# Extrude
from ddgclib.geometry._complex_operations import extrude
HC = extrude(HC, L, axis=1, cdist=1e-10)

HC.plot_complex()
# Out:
# WARNING:root:Warning, no associated scalar field found. Not plotting contour_plot.
# WARNING:root:Warning, no associated scalar field found. Not plotting surface field.
# === 2D Planar Channel Test (optional) ===
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 19
#      16 from ddgclib.geometry._complex_operations import extrude
#      17 HC = extrude(HC, L, axis=1, cdist=1e-10)
# ---> 19 HC.plot_complex()
#
# File ~/projects/ddgclib/hyperct/_complex.py:2566, in Complex.plot_complex(self, **kwargs)
#    2565 def plot_complex(self, **kwargs):
# -> 2566     return _plotting.plot_complex(self, **kwargs)
#
# ...
