# %% [markdown]
# # Embedded hyperct dual meshes
#
# In this notebook we develop a method to compute dual vertices and store in a hyperct cache called `v.nd`. These are then used to compute dual areas and volumes efficiently without the need to recompute dual volumes using cotan formula.
